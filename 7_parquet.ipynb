# %%
import os
import base64
from PIL import Image
import io
import pandas as pd
import os

# Chemin du dossier contenant les fichiers Parquet
input_dir = "downloads/product_eval/"

# Dictionnaire pour stocker les DataFrames
dataframes = {}

# Parcourir tous les fichiers dans le dossier
for i, file_name in enumerate(os.listdir(input_dir), start=1):
    count = 1
    if file_name.endswith(".parquet"):
        file_path = os.path.join(input_dir, file_name)
        print(f"Chargement du fichier : {file_path}")
        
        # Charger le fichier Parquet
        df = pd.read_parquet(file_path)

        # Ajouter le DataFrame au dictionnaire avec un nom dynamique
        dataframes[f"df{i}"] = df
# Out:
# Chargement du fichier : downloads/product_eval/test-00001-of-00003.parquet
# Chargement du fichier : downloads/product_eval/test-00002-of-00003.parquet
# Chargement du fichier : downloads/product_eval/test-00000-of-00003.parquet

# %%
df1 = dataframes["df1"]
df1
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFF\x9c;\x00\x00WEBPVP8 \x90;\x00...  id-B00O4AJHGA  None
# 1      {'bytes': b'RIFF\xae.\x00\x00WEBPVP8 \xa2.\x00...  id-B00O4CVNHE  None
# 2      {'bytes': b'RIFF\xd2\x19\x00\x00WEBPVP8 \xc6\x...  id-B00O4DGXDM  None
# 3      {'bytes': b'RIFFv\x1f\x00\x00WEBPVP8 j\x1f\x00...  id-B00O4DJEO2  None
# 4      {'bytes': b'RIFF\x96\x05\x00\x00WEBPVP8 \x8a\x...  id-B00O4EUUP8  None
# ...                                                  ...            ...   ...
# 33328  {'bytes': b'RIFF\xf86\x00\x00WEBPVP8 \xec6\x00...  id-B07Q92SY6D  None
# 33329  {'bytes': b'RIFFT.\x00\x00WEBPVP8 H.\x00\x00\x...  id-B07Q93CYWQ  None
# 33330  {'bytes': b'RIFF\x10\x1f\x00\x00WEBPVP8 \x04\x...  id-B07Q98DRK5  None
# 33331  {'bytes': b'RIFF\x8a[\x00\x00WEBPVP8 ~[\x00\x0...  id-B07Q9HTZMP  None
# 33332  {'bytes': b'RIFF\x98\x0b\x00\x00WEBPVP8 \x8c\x...  id-B07Q9J3FVQ  None
#
#                                                    title  position
# 0                                             Dr Who:076         0
# 1                                    Faust (Illustrated)         0
# 2      TowelSelections Men's Robe, Turkish Cotton Kim...         0
# 3      CafePress I SCRUB ST Stainless Steel Travel Mu...         0
# 4      5/6 Year Old Fully Pinnable Child Dress Form M...         0
# ...                                                  ...       ...
# 33328  SANDALUP Flat Sandals for Women Summer Beach S...         0
# 33329  S.H.Figuarts Action Figure Iron Man Mark 3 Abo...         0
# 33330  MEETCCY Original 925 Sterling Silver Red Ename...         0
# 33331  Sousuoty Batwing Sleeve Tops for Women Loose F...         0
# 33332  Chargances Black Suede Moon Crescent Choker Bo...         0
#
# [33333 rows x 5 columns]

# %%
df2 = dataframes["df2"]
df2
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFFXV\x00\x00WEBPVP8 LV\x00\x00P\...  id-B07Q9J7JTW  None
# 1      {'bytes': b'RIFF\x8e\x1d\x00\x00WEBPVP8 \x82\x...  id-B07Q9LD5CF  None
# 2      {'bytes': b'RIFF\xd0#\x00\x00WEBPVP8 \xc4#\x00...  id-B07Q9LH8SP  None
# 3      {'bytes': b'RIFF\xbcX\x00\x00WEBPVP8 \xb0X\x00...  id-B07Q9LJ7TJ  None
# 4      {'bytes': b'RIFF\xa4\\\x00\x00WEBPVP8 \x98\\\x...  id-B07Q9LJBVF  None
# ...                                                  ...            ...   ...
# 33328  {'bytes': b'RIFF\xd2\x18\x00\x00WEBPVP8 \xc6\x...  id-B0CKMPX4S1  None
# 33329  {'bytes': b'RIFFB\x1c\x00\x00WEBPVP8 6\x1c\x00...  id-B0CKR2W4NZ  None
# 33330  {'bytes': b'RIFF\xd6\x1d\x00\x00WEBPVP8 \xca\x...  id-B0CKSG3K3N  None
# 33331  {'bytes': b'RIFF$\'\x00\x00WEBPVP8 \x18\'\x00\...  id-B0CKSR5VMV  None
# 33332  {'bytes': b'RIFF\xa2,\x00\x00WEBPVP8 \x96,\x00...  id-B0CKWTP4F5  None
#
#                                                    title  position
# 0      172 Pcs Zipper Replacement Zipper Repair Kit Z...         0
# 1      DWCN Total Privacy Room Divider Blackout Curta...         0
# 2      Benificer Pull Up Bar Set - 3 in 1 Doorway Chi...         0
# 3                 EverOne Survival First Aid Kit - Black         0
# 4      LEINASEN Little Kids Girl's Beach Crochet Mesh...         0
# ...                                                  ...       ...
# 33328  adidas Women's Itavic 3-Stripes Midweight Hood...         0
# 33329  BETHZA Diamond Pearl Necklace for Women Sterli...         0
# 33330  POWEART 30Kpa Cordless Vacuum Cleaner, 8-in-1 ...         0
# 33331  Rain Cloud Humidifier Water Drip, 2 in 1 Humid...         0
# 33332  Sensationnel X-pression prestretched braiding ...         0
#
# [33333 rows x 5 columns]

# %%
df3 = dataframes["df3"]
df3
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFF~\x1e\x00\x00WEBPVP8 r\x1e\x00...  id-0002216949  None
# 1      {'bytes': b'RIFF:\x13\x00\x00WEBPVP8 .\x13\x00...  id-0006128513  None
# 2      {'bytes': b'RIFF\x1a\x1e\x00\x00WEBPVP8 \x0e\x...  id-0006338658  None
# 3      {'bytes': b'RIFF\xb2r\x00\x00WEBPVP8 \xa6r\x00...  id-0006483682  None
# 4      {'bytes': b'RIFFN\'\x00\x00WEBPVP8 B\'\x00\x00...  id-0006511252  None
# ...                                                  ...            ...   ...
# 33329  {'bytes': b'RIFF\x04U\x00\x00WEBPVP8 \xf8T\x00...  id-B00O40V55G  None
# 33330  {'bytes': b'RIFF>.\x00\x00WEBPVP8 2.\x00\x00\x...  id-B00O45QD8K  None
# 33331  {'bytes': b'RIFF"\x15\x00\x00WEBPVP8 \x16\x15\...  id-B00O46PUMY  None
# 33332  {'bytes': b'RIFF&\x10\x00\x00WEBPVP8 \x1a\x10\...  id-B00O472MO2  None
# 33333  {'bytes': b'RIFF \x11\x00\x00WEBPVP8 \x14\x11\...  id-B00O4A6PTW  None
#
#                                                    title  position
# 0                                                 Ransom         0
# 1                                    Caravan to Vaccares         0
# 2      Chronicles of Wasted Time: The Infernal Grove ...         0
# 3                                           Dragonshadow         0
# 4      Flashman (The Flashman Papers, Book 1) (The Fl...         0
# ...                                                  ...       ...
# 33329  Pathfinder Adventure Card Game: Skull & Shackl...         0
# 33330           Maxpedition Proteus Versipack Waist Pack         0
# 33331  Westcott Kids Non-Stick Scissors, Blunt, 5", C...         0
# 33332  Kaufhof KSP15 Woodworking Table Saw Safety Pus...         0
# 33333  it luggage Mega lite Luggage Spinner Collectio...         0
#
# [33334 rows x 5 columns]

# %%
# Chemin de sortie pour enregistrer les images
output_dir = "images_output/1/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
for index, row in df1.iterrows():
    # Récupérer l'image encodée (Base64 ou bytes)
    image_data = row['image']['bytes']
    
    # Créer un nom de fichier basé sur l'index ou une autre colonne
    file_name = f"image_{index}.png"
    file_path = os.path.join(output_dir, file_name)

    try:
        # Si l'image est encodée en Base64, la décoder
        if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
            image_data = base64.b64decode(image_data)
        
        # Ouvrir l'image et la sauvegarder
        image = Image.open(io.BytesIO(image_data))
        image.save(file_path, format="PNG")
        print(f"Image sauvegardée : {file_path}")
    except Exception as e:
        print(f"Erreur pour l'index {index}: {e}")
# Out:
# Image sauvegardée : images_output/1/image_0.png
# Image sauvegardée : images_output/1/image_1.png
# Image sauvegardée : images_output/1/image_2.png
# Image sauvegardée : images_output/1/image_3.png
# Image sauvegardée : images_output/1/image_4.png
# Image sauvegardée : images_output/1/image_5.png
# Image sauvegardée : images_output/1/image_6.png
# Image sauvegardée : images_output/1/image_7.png
# Image sauvegardée : images_output/1/image_8.png
# Image sauvegardée : images_output/1/image_9.png
# Image sauvegardée : images_output/1/image_10.png
# Image sauvegardée : images_output/1/image_11.png
# Image sauvegardée : images_output/1/image_12.png
# Image sauvegardée : images_output/1/image_13.png
# Image sauvegardée : images_output/1/image_14.png
# Image sauvegardée : images_output/1/image_15.png
# Image sauvegardée : images_output/1/image_16.png
# Image sauvegardée : images_output/1/image_17.png
# Image sauvegardée : images_output/1/image_18.png
# Image sauvegardée : images_output/1/image_19.png
# Image sauvegardée : images_output/1/image_20.png
# Image sauvegardée : images_output/1/image_21.png
# Image sauvegardée : images_output/1/image_22.png
# Image sauvegardée : images_output/1/image_23.png
# Image sauvegardée : images_output/1/image_24.png
# Image sauvegardée : images_output/1/image_25.png
# Image sauvegardée : images_output/1/image_26.png
# Image sauvegardée : images_output/1/image_27.png
# Image sauvegardée : images_output/1/image_28.png
# Image sauvegardée : images_output/1/image_29.png
# Image sauvegardée : images_output/1/image_30.png
# Image sauvegardée : images_output/1/image_31.png
# Image sauvegardée : images_output/1/image_32.png
# Image sauvegardée : images_output/1/image_33.png
# Image sauvegardée : images_output/1/image_34.png
# Image sauvegardée : images_output/1/image_35.png
# Image sauvegardée : images_output/1/image_36.png
# Image sauvegardée : images_output/1/image_37.png
# Image sauvegardée : images_output/1/image_38.png
# Image sauvegardée : images_output/1/image_39.png
# Image sauvegardée : images_output/1/image_40.png
# Image sauvegardée : images_output/1/image_41.png
# Image sauvegardée : images_output/1/image_42.png
# Image sauvegardée : images_output/1/image_43.png
# Image sauvegardée : images_output/1/image_44.png
# Image sauvegardée : images_output/1/image_45.png
# Image sauvegardée : images_output/1/image_46.png
# Image sauvegardée : images_output/1/image_47.png
# Image sauvegardée : images_output/1/image_48.png
# Image sauvegardée : images_output/1/image_49.png
# Image sauvegardée : images_output/1/image_50.png
# Image sauvegardée : images_output/1/image_51.png
# Image sauvegardée : images_output/1/image_52.png
# Image sauvegardée : images_output/1/image_53.png
# Image sauvegardée : images_output/1/image_54.png
# Image sauvegardée : images_output/1/image_55.png
# Image sauvegardée : images_output/1/image_56.png
# Image sauvegardée : images_output/1/image_57.png
# Image sauvegardée : images_output/1/image_58.png
# Image sauvegardée : images_output/1/image_59.png
# Image sauvegardée : images_output/1/image_60.png
# Image sauvegardée : images_output/1/image_61.png
# Image sauvegardée : images_output/1/image_62.png
# Image sauvegardée : images_output/1/image_63.png
# Image sauvegardée : images_output/1/image_64.png
# Image sauvegardée : images_output/1/image_65.png
# Image sauvegardée : images_output/1/image_66.png
# Image sauvegardée : images_output/1/image_67.png
# Image sauvegardée : images_output/1/image_68.png
# Image sauvegardée : images_output/1/image_69.png
# Image sauvegardée : images_output/1/image_70.png
# Image sauvegardée : images_output/1/image_71.png
# Image sauvegardée : images_output/1/image_72.png
# Image sauvegardée : images_output/1/image_73.png
# Image sauvegardée : images_output/1/image_74.png
# Image sauvegardée : images_output/1/image_75.png
# Image sauvegardée : images_output/1/image_76.png
# Image sauvegardée : images_output/1/image_77.png
# Image sauvegardée : images_output/1/image_78.png
# Image sauvegardée : images_output/1/image_79.png
# Image sauvegardée : images_output/1/image_80.png
# Image sauvegardée : images_output/1/image_81.png
# Image sauvegardée : images_output/1/image_82.png
# Image sauvegardée : images_output/1/image_83.png
# Image sauvegardée : images_output/1/image_84.png
# Image sauvegardée : images_output/1/image_85.png
# Image sauvegardée : images_output/1/image_86.png
# Image sauvegardée : images_output/1/image_87.png
# Image sauvegardée : images_output/1/image_88.png
# Image sauvegardée : images_output/1/image_89.png
# Image sauvegardée : images_output/1/image_90.png
# Image sauvegardée : images_output/1/image_91.png
# Image sauvegardée : images_output/1/image_92.png
# Image sauvegardée : images_output/1/image_93.png
# Image sauvegardée : images_output/1/image_94.png
# Image sauvegardée : images_output/1/image_95.png
# Image sauvegardée : images_output/1/image_96.png
# Image sauvegardée : images_output/1/image_97.png
# Image sauvegardée : images_output/1/image_98.png
# Image sauvegardée : images_output/1/image_99.png
# Image sauvegardée : images_output/1/image_100.png
# Image sauvegardée : images_output/1/image_101.png
# Image sauvegardée : images_output/1/image_102.png
# Image sauvegardée : images_output/1/image_103.png
# Image sauvegardée : images_output/1/image_104.png
# Image sauvegardée : images_output/1/image_105.png
# Image sauvegardée : images_output/1/image_106.png
# Image sauvegardée : images_output/1/image_107.png
# Image sauvegardée : images_output/1/image_108.png
# Image sauvegardée : images_output/1/image_109.png
# Image sauvegardée : images_output/1/image_110.png
# Image sauvegardée : images_output/1/image_111.png
# Image sauvegardée : images_output/1/image_112.png
# Image sauvegardée : images_output/1/image_113.png
# Image sauvegardée : images_output/1/image_114.png
# Image sauvegardée : images_output/1/image_115.png
# Image sauvegardée : images_output/1/image_116.png
# Image sauvegardée : images_output/1/image_117.png
# Image sauvegardée : images_output/1/image_118.png
# Image sauvegardée : images_output/1/image_119.png
# Image sauvegardée : images_output/1/image_120.png
# Image sauvegardée : images_output/1/image_121.png
# Image sauvegardée : images_output/1/image_122.png
# Image sauvegardée : images_output/1/image_123.png
# Image sauvegardée : images_output/1/image_124.png
# Image sauvegardée : images_output/1/image_125.png
# Image sauvegardée : images_output/1/image_126.png
# Image sauvegardée : images_output/1/image_127.png
# Image sauvegardée : images_output/1/image_128.png
# Image sauvegardée : images_output/1/image_129.png
# Image sauvegardée : images_output/1/image_130.png
# Image sauvegardée : images_output/1/image_131.png
# Image sauvegardée : images_output/1/image_132.png
# Image sauvegardée : images_output/1/image_133.png
# Image sauvegardée : images_output/1/image_134.png
# Image sauvegardée : images_output/1/image_135.png
# Image sauvegardée : images_output/1/image_136.png
# Image sauvegardée : images_output/1/image_137.png
# Image sauvegardée : images_output/1/image_138.png
# Image sauvegardée : images_output/1/image_139.png
# Image sauvegardée : images_output/1/image_140.png
# Image sauvegardée : images_output/1/image_141.png
# Image sauvegardée : images_output/1/image_142.png
# Image sauvegardée : images_output/1/image_143.png
# Image sauvegardée : images_output/1/image_144.png
# Image sauvegardée : images_output/1/image_145.png
# Image sauvegardée : images_output/1/image_146.png
# Image sauvegardée : images_output/1/image_147.png
# Image sauvegardée : images_output/1/image_148.png
# Image sauvegardée : images_output/1/image_149.png
# Image sauvegardée : images_output/1/image_150.png
# Image sauvegardée : images_output/1/image_151.png
# Image sauvegardée : images_output/1/image_152.png
# Image sauvegardée : images_output/1/image_153.png
# Image sauvegardée : images_output/1/image_154.png
# Image sauvegardée : images_output/1/image_155.png
# Image sauvegardée : images_output/1/image_156.png
# Image sauvegardée : images_output/1/image_157.png
# Image sauvegardée : images_output/1/image_158.png
# Image sauvegardée : images_output/1/image_159.png
# Image sauvegardée : images_output/1/image_160.png
# Image sauvegardée : images_output/1/image_161.png
# Image sauvegardée : images_output/1/image_162.png
# Image sauvegardée : images_output/1/image_163.png
# Image sauvegardée : images_output/1/image_164.png
# Image sauvegardée : images_output/1/image_165.png
# Image sauvegardée : images_output/1/image_166.png
# Image sauvegardée : images_output/1/image_167.png
# Image sauvegardée : images_output/1/image_168.png
# Image sauvegardée : images_output/1/image_169.png
# Image sauvegardée : images_output/1/image_170.png
# Image sauvegardée : images_output/1/image_171.png
# Image sauvegardée : images_output/1/image_172.png
# Image sauvegardée : images_output/1/image_173.png
# Image sauvegardée : images_output/1/image_174.png
# Image sauvegardée : images_output/1/image_175.png
# Image sauvegardée : images_output/1/image_176.png
# Image sauvegardée : images_output/1/image_177.png
# Image sauvegardée : images_output/1/image_178.png
# Image sauvegardée : images_output/1/image_179.png
# Image sauvegardée : images_output/1/image_180.png
# Image sauvegardée : images_output/1/image_181.png
# Image sauvegardée : images_output/1/image_182.png
# Image sauvegardée : images_output/1/image_183.png
# Image sauvegardée : images_output/1/image_184.png
# Image sauvegardée : images_output/1/image_185.png
# Image sauvegardée : images_output/1/image_186.png
# Image sauvegardée : images_output/1/image_187.png
# Image sauvegardée : images_output/1/image_188.png
# Image sauvegardée : images_output/1/image_189.png
# Image sauvegardée : images_output/1/image_190.png
# Image sauvegardée : images_output/1/image_191.png
# Image sauvegardée : images_output/1/image_192.png
# Image sauvegardée : images_output/1/image_193.png
# Image sauvegardée : images_output/1/image_194.png
# Image sauvegardée : images_output/1/image_195.png
# Image sauvegardée : images_output/1/image_196.png
# Image sauvegardée : images_output/1/image_197.png
# Image sauvegardée : images_output/1/image_198.png
# Image sauvegardée : images_output/1/image_199.png
# Image sauvegardée : images_output/1/image_200.png
# Image sauvegardée : images_output/1/image_201.png
# Image sauvegardée : images_output/1/image_202.png
# Image sauvegardée : images_output/1/image_203.png
# Image sauvegardée : images_output/1/image_204.png
# Image sauvegardée : images_output/1/image_205.png
# Image sauvegardée : images_output/1/image_206.png
# Image sauvegardée : images_output/1/image_207.png
# Image sauvegardée : images_output/1/image_208.png
# Image sauvegardée : images_output/1/image_209.png
# Image sauvegardée : images_output/1/image_210.png
# Image sauvegardée : images_output/1/image_211.png
# Image sauvegardée : images_output/1/image_212.png
# Image sauvegardée : images_output/1/image_213.png
# Image sauvegardée : images_output/1/image_214.png
# Image sauvegardée : images_output/1/image_215.png
# Image sauvegardée : images_output/1/image_216.png
# Image sauvegardée : images_output/1/image_217.png
# Image sauvegardée : images_output/1/image_218.png
# Image sauvegardée : images_output/1/image_219.png
# Image sauvegardée : images_output/1/image_220.png
# Image sauvegardée : images_output/1/image_221.png
# Image sauvegardée : images_output/1/image_222.png
# Image sauvegardée : images_output/1/image_223.png
# Image sauvegardée : images_output/1/image_224.png
# Image sauvegardée : images_output/1/image_225.png
# Image sauvegardée : images_output/1/image_226.png
# Image sauvegardée : images_output/1/image_227.png
# Image sauvegardée : images_output/1/image_228.png
# Image sauvegardée : images_output/1/image_229.png
# Image sauvegardée : images_output/1/image_230.png
# Image sauvegardée : images_output/1/image_231.png
# Image sauvegardée : images_output/1/image_232.png
# Image sauvegardée : images_output/1/image_233.png
# Image sauvegardée : images_output/1/image_234.png
# Image sauvegardée : images_output/1/image_235.png
# Image sauvegardée : images_output/1/image_236.png
# Image sauvegardée : images_output/1/image_237.png
# Image sauvegardée : images_output/1/image_238.png
# Image sauvegardée : images_output/1/image_239.png
# Image sauvegardée : images_output/1/image_240.png
# Image sauvegardée : images_output/1/image_241.png
# Image sauvegardée : images_output/1/image_242.png
# Image sauvegardée : images_output/1/image_243.png
# Image sauvegardée : images_output/1/image_244.png
# Image sauvegardée : images_output/1/image_245.png
# Image sauvegardée : images_output/1/image_246.png
# Image sauvegardée : images_output/1/image_247.png
# Image sauvegardée : images_output/1/image_248.png
# Image sauvegardée : images_output/1/image_249.png
# Image sauvegardée : images_output/1/image_250.png
# Image sauvegardée : images_output/1/image_251.png
# Image sauvegardée : images_output/1/image_252.png
# Image sauvegardée : images_output/1/image_253.png
# Image sauvegardée : images_output/1/image_254.png
# Image sauvegardée : images_output/1/image_255.png
# Image sauvegardée : images_output/1/image_256.png
# Image sauvegardée : images_output/1/image_257.png
# Image sauvegardée : images_output/1/image_258.png
# Image sauvegardée : images_output/1/image_259.png
# Image sauvegardée : images_output/1/image_260.png
# Image sauvegardée : images_output/1/image_261.png
# Image sauvegardée : images_output/1/image_262.png
# Image sauvegardée : images_output/1/image_263.png
# Image sauvegardée : images_output/1/image_264.png
# Image sauvegardée : images_output/1/image_265.png
# Image sauvegardée : images_output/1/image_266.png
# Image sauvegardée : images_output/1/image_267.png
# Image sauvegardée : images_output/1/image_268.png
# Image sauvegardée : images_output/1/image_269.png
# Image sauvegardée : images_output/1/image_270.png
# Image sauvegardée : images_output/1/image_271.png
# Image sauvegardée : images_output/1/image_272.png
# Image sauvegardée : images_output/1/image_273.png
# Image sauvegardée : images_output/1/image_274.png
# Image sauvegardée : images_output/1/image_275.png
# Image sauvegardée : images_output/1/image_276.png
# Image sauvegardée : images_output/1/image_277.png
# Image sauvegardée : images_output/1/image_278.png
# Image sauvegardée : images_output/1/image_279.png
# Image sauvegardée : images_output/1/image_280.png
# Image sauvegardée : images_output/1/image_281.png
# Image sauvegardée : images_output/1/image_282.png
# Image sauvegardée : images_output/1/image_283.png
# Image sauvegardée : images_output/1/image_284.png
# Image sauvegardée : images_output/1/image_285.png
# Image sauvegardée : images_output/1/image_286.png
# Image sauvegardée : images_output/1/image_287.png
# Image sauvegardée : images_output/1/image_288.png
# Image sauvegardée : images_output/1/image_289.png
# Image sauvegardée : images_output/1/image_290.png
# Image sauvegardée : images_output/1/image_291.png
# Image sauvegardée : images_output/1/image_292.png
# Image sauvegardée : images_output/1/image_293.png
# Image sauvegardée : images_output/1/image_294.png
# Image sauvegardée : images_output/1/image_295.png
# Image sauvegardée : images_output/1/image_296.png
# Image sauvegardée : images_output/1/image_297.png
# Image sauvegardée : images_output/1/image_298.png
# Image sauvegardée : images_output/1/image_299.png
# Image sauvegardée : images_output/1/image_300.png
# Image sauvegardée : images_output/1/image_301.png
# Image sauvegardée : images_output/1/image_302.png
# Image sauvegardée : images_output/1/image_303.png
# Image sauvegardée : images_output/1/image_304.png
# Image sauvegardée : images_output/1/image_305.png
# Image sauvegardée : images_output/1/image_306.png
# Image sauvegardée : images_output/1/image_307.png
# Image sauvegardée : images_output/1/image_308.png
# Image sauvegardée : images_output/1/image_309.png
# Image sauvegardée : images_output/1/image_310.png
# Image sauvegardée : images_output/1/image_311.png
# Image sauvegardée : images_output/1/image_312.png
# Image sauvegardée : images_output/1/image_313.png
# Image sauvegardée : images_output/1/image_314.png
# Image sauvegardée : images_output/1/image_315.png
# Image sauvegardée : images_output/1/image_316.png
# Image sauvegardée : images_output/1/image_317.png
# Image sauvegardée : images_output/1/image_318.png
# Image sauvegardée : images_output/1/image_319.png
# Image sauvegardée : images_output/1/image_320.png
# Image sauvegardée : images_output/1/image_321.png
# Image sauvegardée : images_output/1/image_322.png
# Image sauvegardée : images_output/1/image_323.png
# Image sauvegardée : images_output/1/image_324.png
# Image sauvegardée : images_output/1/image_325.png
# Image sauvegardée : images_output/1/image_326.png
# Image sauvegardée : images_output/1/image_327.png
# Image sauvegardée : images_output/1/image_328.png
# Image sauvegardée : images_output/1/image_329.png
# Image sauvegardée : images_output/1/image_330.png
# Image sauvegardée : images_output/1/image_331.png
# Image sauvegardée : images_output/1/image_332.png
# Image sauvegardée : images_output/1/image_333.png
# Image sauvegardée : images_output/1/image_334.png
# Image sauvegardée : images_output/1/image_335.png
# Image sauvegardée : images_output/1/image_336.png
# Image sauvegardée : images_output/1/image_337.png
# Image sauvegardée : images_output/1/image_338.png
# Image sauvegardée : images_output/1/image_339.png
# Image sauvegardée : images_output/1/image_340.png
# Image sauvegardée : images_output/1/image_341.png
# Image sauvegardée : images_output/1/image_342.png
# Image sauvegardée : images_output/1/image_343.png
# Image sauvegardée : images_output/1/image_344.png
# Image sauvegardée : images_output/1/image_345.png
# Image sauvegardée : images_output/1/image_346.png
# Image sauvegardée : images_output/1/image_347.png
# Image sauvegardée : images_output/1/image_348.png
# Image sauvegardée : images_output/1/image_349.png
# Image sauvegardée : images_output/1/image_350.png
# Image sauvegardée : images_output/1/image_351.png
# Image sauvegardée : images_output/1/image_352.png
# Image sauvegardée : images_output/1/image_353.png
# Image sauvegardée : images_output/1/image_354.png
# Image sauvegardée : images_output/1/image_355.png
# Image sauvegardée : images_output/1/image_356.png
# Image sauvegardée : images_output/1/image_357.png
# Image sauvegardée : images_output/1/image_358.png
# Image sauvegardée : images_output/1/image_359.png
# Image sauvegardée : images_output/1/image_360.png
# Image sauvegardée : images_output/1/image_361.png
# Image sauvegardée : images_output/1/image_362.png
# Image sauvegardée : images_output/1/image_363.png
# Image sauvegardée : images_output/1/image_364.png
# Image sauvegardée : images_output/1/image_365.png
# Image sauvegardée : images_output/1/image_366.png
# Image sauvegardée : images_output/1/image_367.png
# Image sauvegardée : images_output/1/image_368.png
# Image sauvegardée : images_output/1/image_369.png
# Image sauvegardée : images_output/1/image_370.png
# Image sauvegardée : images_output/1/image_371.png
# Image sauvegardée : images_output/1/image_372.png
# Image sauvegardée : images_output/1/image_373.png
# Image sauvegardée : images_output/1/image_374.png
# Image sauvegardée : images_output/1/image_375.png
# Image sauvegardée : images_output/1/image_376.png
# Image sauvegardée : images_output/1/image_377.png
# Image sauvegardée : images_output/1/image_378.png
# Image sauvegardée : images_output/1/image_379.png
# Image sauvegardée : images_output/1/image_380.png
# Image sauvegardée : images_output/1/image_381.png
# Image sauvegardée : images_output/1/image_382.png
# Image sauvegardée : images_output/1/image_383.png
# Image sauvegardée : images_output/1/image_384.png
# Image sauvegardée : images_output/1/image_385.png
# Image sauvegardée : images_output/1/image_386.png
# Image sauvegardée : images_output/1/image_387.png
# Image sauvegardée : images_output/1/image_388.png
# Image sauvegardée : images_output/1/image_389.png
# Image sauvegardée : images_output/1/image_390.png
# Image sauvegardée : images_output/1/image_391.png
# Image sauvegardée : images_output/1/image_392.png
# Image sauvegardée : images_output/1/image_393.png
# Image sauvegardée : images_output/1/image_394.png
# Image sauvegardée : images_output/1/image_395.png
# Image sauvegardée : images_output/1/image_396.png
# Image sauvegardée : images_output/1/image_397.png
# Image sauvegardée : images_output/1/image_398.png
# Image sauvegardée : images_output/1/image_399.png
# Image sauvegardée : images_output/1/image_400.png
# Image sauvegardée : images_output/1/image_401.png
# Image sauvegardée : images_output/1/image_402.png
# Image sauvegardée : images_output/1/image_403.png
# Image sauvegardée : images_output/1/image_404.png
# Image sauvegardée : images_output/1/image_405.png
# Image sauvegardée : images_output/1/image_406.png
# Image sauvegardée : images_output/1/image_407.png
# Image sauvegardée : images_output/1/image_408.png
# Image sauvegardée : images_output/1/image_409.png
# Image sauvegardée : images_output/1/image_410.png
# Image sauvegardée : images_output/1/image_411.png
# Image sauvegardée : images_output/1/image_412.png
# Image sauvegardée : images_output/1/image_413.png
# Image sauvegardée : images_output/1/image_414.png
# Image sauvegardée : images_output/1/image_415.png
# Image sauvegardée : images_output/1/image_416.png
# Image sauvegardée : images_output/1/image_417.png
# Image sauvegardée : images_output/1/image_418.png
# Image sauvegardée : images_output/1/image_419.png
# Image sauvegardée : images_output/1/image_420.png
# Image sauvegardée : images_output/1/image_421.png
# Image sauvegardée : images_output/1/image_422.png
# Image sauvegardée : images_output/1/image_423.png
# Image sauvegardée : images_output/1/image_424.png
# Image sauvegardée : images_output/1/image_425.png
# Image sauvegardée : images_output/1/image_426.png
# Image sauvegardée : images_output/1/image_427.png
# Image sauvegardée : images_output/1/image_428.png
# Image sauvegardée : images_output/1/image_429.png
# Image sauvegardée : images_output/1/image_430.png
# Image sauvegardée : images_output/1/image_431.png
# Image sauvegardée : images_output/1/image_432.png
# Image sauvegardée : images_output/1/image_433.png
# Image sauvegardée : images_output/1/image_434.png
# Image sauvegardée : images_output/1/image_435.png
# Image sauvegardée : images_output/1/image_436.png
# Image sauvegardée : images_output/1/image_437.png
# Image sauvegardée : images_output/1/image_438.png
# Image sauvegardée : images_output/1/image_439.png
# Image sauvegardée : images_output/1/image_440.png
# Image sauvegardée : images_output/1/image_441.png
# Image sauvegardée : images_output/1/image_442.png
# Image sauvegardée : images_output/1/image_443.png
# Image sauvegardée : images_output/1/image_444.png
# Image sauvegardée : images_output/1/image_445.png
# Image sauvegardée : images_output/1/image_446.png
# Image sauvegardée : images_output/1/image_447.png
# Image sauvegardée : images_output/1/image_448.png
# Image sauvegardée : images_output/1/image_449.png
# Image sauvegardée : images_output/1/image_450.png
# Image sauvegardée : images_output/1/image_451.png
# Image sauvegardée : images_output/1/image_452.png
# Image sauvegardée : images_output/1/image_453.png
# Image sauvegardée : images_output/1/image_454.png
# Image sauvegardée : images_output/1/image_455.png
# Image sauvegardée : images_output/1/image_456.png
# Image sauvegardée : images_output/1/image_457.png
# Image sauvegardée : images_output/1/image_458.png
# Image sauvegardée : images_output/1/image_459.png
# Image sauvegardée : images_output/1/image_460.png
# Image sauvegardée : images_output/1/image_461.png
# Image sauvegardée : images_output/1/image_462.png
# Image sauvegardée : images_output/1/image_463.png
# Image sauvegardée : images_output/1/image_464.png
# Image sauvegardée : images_output/1/image_465.png
# Image sauvegardée : images_output/1/image_466.png
# Image sauvegardée : images_output/1/image_467.png
# Image sauvegardée : images_output/1/image_468.png
# Image sauvegardée : images_output/1/image_469.png
# Image sauvegardée : images_output/1/image_470.png
# Image sauvegardée : images_output/1/image_471.png
# Image sauvegardée : images_output/1/image_472.png
# Image sauvegardée : images_output/1/image_473.png
# Image sauvegardée : images_output/1/image_474.png
# Image sauvegardée : images_output/1/image_475.png
# Image sauvegardée : images_output/1/image_476.png
# Image sauvegardée : images_output/1/image_477.png
# Image sauvegardée : images_output/1/image_478.png
# Image sauvegardée : images_output/1/image_479.png
# Image sauvegardée : images_output/1/image_480.png
# Image sauvegardée : images_output/1/image_481.png
# Image sauvegardée : images_output/1/image_482.png
# Image sauvegardée : images_output/1/image_483.png
# Image sauvegardée : images_output/1/image_484.png
# Image sauvegardée : images_output/1/image_485.png
# Image sauvegardée : images_output/1/image_486.png
# Image sauvegardée : images_output/1/image_487.png
# Image sauvegardée : images_output/1/image_488.png
# Image sauvegardée : images_output/1/image_489.png
# Image sauvegardée : images_output/1/image_490.png
# Image sauvegardée : images_output/1/image_491.png
# Image sauvegardée : images_output/1/image_492.png
# Image sauvegardée : images_output/1/image_493.png
# Image sauvegardée : images_output/1/image_494.png
# Image sauvegardée : images_output/1/image_495.png
# Image sauvegardée : images_output/1/image_496.png
# Image sauvegardée : images_output/1/image_497.png
# Image sauvegardée : images_output/1/image_498.png
# Image sauvegardée : images_output/1/image_499.png
# Image sauvegardée : images_output/1/image_500.png
# Image sauvegardée : images_output/1/image_501.png
# Image sauvegardée : images_output/1/image_502.png
# Image sauvegardée : images_output/1/image_503.png
# Image sauvegardée : images_output/1/image_504.png
# Image sauvegardée : images_output/1/image_505.png
# Image sauvegardée : images_output/1/image_506.png
# Image sauvegardée : images_output/1/image_507.png
# Image sauvegardée : images_output/1/image_508.png
# Image sauvegardée : images_output/1/image_509.png
# Image sauvegardée : images_output/1/image_510.png
# Image sauvegardée : images_output/1/image_511.png
# Image sauvegardée : images_output/1/image_512.png
# Image sauvegardée : images_output/1/image_513.png
# Image sauvegardée : images_output/1/image_514.png
# Image sauvegardée : images_output/1/image_515.png
# Image sauvegardée : images_output/1/image_516.png
# Image sauvegardée : images_output/1/image_517.png
# Image sauvegardée : images_output/1/image_518.png
# Image sauvegardée : images_output/1/image_519.png
# Image sauvegardée : images_output/1/image_520.png
# Image sauvegardée : images_output/1/image_521.png
# Image sauvegardée : images_output/1/image_522.png
# Image sauvegardée : images_output/1/image_523.png
# Image sauvegardée : images_output/1/image_524.png
# Image sauvegardée : images_output/1/image_525.png
# Image sauvegardée : images_output/1/image_526.png
# Image sauvegardée : images_output/1/image_527.png
# Image sauvegardée : images_output/1/image_528.png
# Image sauvegardée : images_output/1/image_529.png
# Image sauvegardée : images_output/1/image_530.png
# Image sauvegardée : images_output/1/image_531.png
# Image sauvegardée : images_output/1/image_532.png
# Image sauvegardée : images_output/1/image_533.png
# Image sauvegardée : images_output/1/image_534.png
# Image sauvegardée : images_output/1/image_535.png
# Image sauvegardée : images_output/1/image_536.png
# Image sauvegardée : images_output/1/image_537.png
# Image sauvegardée : images_output/1/image_538.png
# Image sauvegardée : images_output/1/image_539.png
# Image sauvegardée : images_output/1/image_540.png
# Image sauvegardée : images_output/1/image_541.png
# Image sauvegardée : images_output/1/image_542.png
# Image sauvegardée : images_output/1/image_543.png
# Image sauvegardée : images_output/1/image_544.png
# Image sauvegardée : images_output/1/image_545.png
# Image sauvegardée : images_output/1/image_546.png
# Image sauvegardée : images_output/1/image_547.png
# Image sauvegardée : images_output/1/image_548.png
# Image sauvegardée : images_output/1/image_549.png
# Image sauvegardée : images_output/1/image_550.png
# Image sauvegardée : images_output/1/image_551.png
# Image sauvegardée : images_output/1/image_552.png
# Image sauvegardée : images_output/1/image_553.png
# Image sauvegardée : images_output/1/image_554.png
# Image sauvegardée : images_output/1/image_555.png
# Image sauvegardée : images_output/1/image_556.png
# Image sauvegardée : images_output/1/image_557.png
# Image sauvegardée : images_output/1/image_558.png
# Image sauvegardée : images_output/1/image_559.png
# Image sauvegardée : images_output/1/image_560.png
# Image sauvegardée : images_output/1/image_561.png
# Image sauvegardée : images_output/1/image_562.png
# Image sauvegardée : images_output/1/image_563.png
# Image sauvegardée : images_output/1/image_564.png
# Image sauvegardée : images_output/1/image_565.png
# Image sauvegardée : images_output/1/image_566.png
# Image sauvegardée : images_output/1/image_567.png
# Image sauvegardée : images_output/1/image_568.png
# Image sauvegardée : images_output/1/image_569.png
# Image sauvegardée : images_output/1/image_570.png
# Image sauvegardée : images_output/1/image_571.png
# Image sauvegardée : images_output/1/image_572.png
# Image sauvegardée : images_output/1/image_573.png
# Image sauvegardée : images_output/1/image_574.png
# Image sauvegardée : images_output/1/image_575.png
# Image sauvegardée : images_output/1/image_576.png
# Image sauvegardée : images_output/1/image_577.png
# Image sauvegardée : images_output/1/image_578.png
# Image sauvegardée : images_output/1/image_579.png
# Image sauvegardée : images_output/1/image_580.png
# Image sauvegardée : images_output/1/image_581.png
# Image sauvegardée : images_output/1/image_582.png
# Image sauvegardée : images_output/1/image_583.png
# Image sauvegardée : images_output/1/image_584.png
# Image sauvegardée : images_output/1/image_585.png
# Image sauvegardée : images_output/1/image_586.png
# Image sauvegardée : images_output/1/image_587.png
# Image sauvegardée : images_output/1/image_588.png
# Image sauvegardée : images_output/1/image_589.png
# Image sauvegardée : images_output/1/image_590.png
# Image sauvegardée : images_output/1/image_591.png
# Image sauvegardée : images_output/1/image_592.png
# Image sauvegardée : images_output/1/image_593.png
# Image sauvegardée : images_output/1/image_594.png
# Image sauvegardée : images_output/1/image_595.png
# Image sauvegardée : images_output/1/image_596.png
# Image sauvegardée : images_output/1/image_597.png
# Image sauvegardée : images_output/1/image_598.png
# Image sauvegardée : images_output/1/image_599.png
# Image sauvegardée : images_output/1/image_600.png
# Image sauvegardée : images_output/1/image_601.png
# Image sauvegardée : images_output/1/image_602.png
# Image sauvegardée : images_output/1/image_603.png
# Image sauvegardée : images_output/1/image_604.png
# Image sauvegardée : images_output/1/image_605.png
# Image sauvegardée : images_output/1/image_606.png
# Image sauvegardée : images_output/1/image_607.png
# Image sauvegardée : images_output/1/image_608.png
# Image sauvegardée : images_output/1/image_609.png
# Image sauvegardée : images_output/1/image_610.png
# Image sauvegardée : images_output/1/image_611.png
# Image sauvegardée : images_output/1/image_612.png
# Image sauvegardée : images_output/1/image_613.png
# Image sauvegardée : images_output/1/image_614.png
# Image sauvegardée : images_output/1/image_615.png
# Image sauvegardée : images_output/1/image_616.png
# Image sauvegardée : images_output/1/image_617.png
# Image sauvegardée : images_output/1/image_618.png
# Image sauvegardée : images_output/1/image_619.png
# Image sauvegardée : images_output/1/image_620.png
# Image sauvegardée : images_output/1/image_621.png
# Image sauvegardée : images_output/1/image_622.png
# Image sauvegardée : images_output/1/image_623.png
# Image sauvegardée : images_output/1/image_624.png
# Image sauvegardée : images_output/1/image_625.png
# Image sauvegardée : images_output/1/image_626.png
# Image sauvegardée : images_output/1/image_627.png
# Image sauvegardée : images_output/1/image_628.png
# Image sauvegardée : images_output/1/image_629.png
# Image sauvegardée : images_output/1/image_630.png
# Image sauvegardée : images_output/1/image_631.png
# Image sauvegardée : images_output/1/image_632.png
# Image sauvegardée : images_output/1/image_633.png
# Image sauvegardée : images_output/1/image_634.png
# Image sauvegardée : images_output/1/image_635.png
# Image sauvegardée : images_output/1/image_636.png
# Image sauvegardée : images_output/1/image_637.png
# Image sauvegardée : images_output/1/image_638.png
# Image sauvegardée : images_output/1/image_639.png
# Image sauvegardée : images_output/1/image_640.png
# Image sauvegardée : images_output/1/image_641.png
# Image sauvegardée : images_output/1/image_642.png
# Image sauvegardée : images_output/1/image_643.png
# Image sauvegardée : images_output/1/image_644.png
# Image sauvegardée : images_output/1/image_645.png
# Image sauvegardée : images_output/1/image_646.png
# Image sauvegardée : images_output/1/image_647.png
# Image sauvegardée : images_output/1/image_648.png
# Image sauvegardée : images_output/1/image_649.png
# Image sauvegardée : images_output/1/image_650.png
# Image sauvegardée : images_output/1/image_651.png
# Image sauvegardée : images_output/1/image_652.png
# Image sauvegardée : images_output/1/image_653.png
# Image sauvegardée : images_output/1/image_654.png
# Image sauvegardée : images_output/1/image_655.png
# Image sauvegardée : images_output/1/image_656.png
# Image sauvegardée : images_output/1/image_657.png
# Image sauvegardée : images_output/1/image_658.png
# Image sauvegardée : images_output/1/image_659.png
# Image sauvegardée : images_output/1/image_660.png
# Image sauvegardée : images_output/1/image_661.png
# Image sauvegardée : images_output/1/image_662.png
# Image sauvegardée : images_output/1/image_663.png
# Image sauvegardée : images_output/1/image_664.png
# Image sauvegardée : images_output/1/image_665.png
# Image sauvegardée : images_output/1/image_666.png
# Image sauvegardée : images_output/1/image_667.png
# Image sauvegardée : images_output/1/image_668.png
# Image sauvegardée : images_output/1/image_669.png
# Image sauvegardée : images_output/1/image_670.png
# Image sauvegardée : images_output/1/image_671.png
# Image sauvegardée : images_output/1/image_672.png
# Image sauvegardée : images_output/1/image_673.png
# Image sauvegardée : images_output/1/image_674.png
# Image sauvegardée : images_output/1/image_675.png
# Image sauvegardée : images_output/1/image_676.png
# Image sauvegardée : images_output/1/image_677.png
# Image sauvegardée : images_output/1/image_678.png
# Image sauvegardée : images_output/1/image_679.png
# Image sauvegardée : images_output/1/image_680.png
# Image sauvegardée : images_output/1/image_681.png
# Image sauvegardée : images_output/1/image_682.png
# Image sauvegardée : images_output/1/image_683.png
# Image sauvegardée : images_output/1/image_684.png
# Image sauvegardée : images_output/1/image_685.png
# Image sauvegardée : images_output/1/image_686.png
# Image sauvegardée : images_output/1/image_687.png
# Image sauvegardée : images_output/1/image_688.png
# Image sauvegardée : images_output/1/image_689.png
# Image sauvegardée : images_output/1/image_690.png
# Image sauvegardée : images_output/1/image_691.png
# Image sauvegardée : images_output/1/image_692.png
# Image sauvegardée : images_output/1/image_693.png
# Image sauvegardée : images_output/1/image_694.png
# Image sauvegardée : images_output/1/image_695.png
# Image sauvegardée : images_output/1/image_696.png
# Image sauvegardée : images_output/1/image_697.png
# Image sauvegardée : images_output/1/image_698.png
# Image sauvegardée : images_output/1/image_699.png
# Image sauvegardée : images_output/1/image_700.png
# Image sauvegardée : images_output/1/image_701.png
# Image sauvegardée : images_output/1/image_702.png
# Image sauvegardée : images_output/1/image_703.png
# Image sauvegardée : images_output/1/image_704.png
# Image sauvegardée : images_output/1/image_705.png
# Image sauvegardée : images_output/1/image_706.png
# Image sauvegardée : images_output/1/image_707.png
# Image sauvegardée : images_output/1/image_708.png
# Image sauvegardée : images_output/1/image_709.png
# Image sauvegardée : images_output/1/image_710.png
# Image sauvegardée : images_output/1/image_711.png
# Image sauvegardée : images_output/1/image_712.png
# Image sauvegardée : images_output/1/image_713.png
# Image sauvegardée : images_output/1/image_714.png
# Image sauvegardée : images_output/1/image_715.png
# Image sauvegardée : images_output/1/image_716.png
# Image sauvegardée : images_output/1/image_717.png
# Image sauvegardée : images_output/1/image_718.png
# Image sauvegardée : images_output/1/image_719.png
# Image sauvegardée : images_output/1/image_720.png
# Image sauvegardée : images_output/1/image_721.png
# Image sauvegardée : images_output/1/image_722.png
# Image sauvegardée : images_output/1/image_723.png
# Image sauvegardée : images_output/1/image_724.png
# Image sauvegardée : images_output/1/image_725.png
# Image sauvegardée : images_output/1/image_726.png
# Image sauvegardée : images_output/1/image_727.png
# Image sauvegardée : images_output/1/image_728.png
# Image sauvegardée : images_output/1/image_729.png
# Image sauvegardée : images_output/1/image_730.png
# Image sauvegardée : images_output/1/image_731.png
# Image sauvegardée : images_output/1/image_732.png
# Image sauvegardée : images_output/1/image_733.png
# Image sauvegardée : images_output/1/image_734.png
# Image sauvegardée : images_output/1/image_735.png
# Image sauvegardée : images_output/1/image_736.png
# Image sauvegardée : images_output/1/image_737.png
# Image sauvegardée : images_output/1/image_738.png
# Image sauvegardée : images_output/1/image_739.png
# Image sauvegardée : images_output/1/image_740.png
# Image sauvegardée : images_output/1/image_741.png
# Image sauvegardée : images_output/1/image_742.png
# Image sauvegardée : images_output/1/image_743.png
# Image sauvegardée : images_output/1/image_744.png
# Image sauvegardée : images_output/1/image_745.png
# Image sauvegardée : images_output/1/image_746.png
# Image sauvegardée : images_output/1/image_747.png
# Image sauvegardée : images_output/1/image_748.png
# Image sauvegardée : images_output/1/image_749.png
# Image sauvegardée : images_output/1/image_750.png
# Image sauvegardée : images_output/1/image_751.png
# Image sauvegardée : images_output/1/image_752.png
# Image sauvegardée : images_output/1/image_753.png
# Image sauvegardée : images_output/1/image_754.png
# Image sauvegardée : images_output/1/image_755.png
# Image sauvegardée : images_output/1/image_756.png
# Image sauvegardée : images_output/1/image_757.png
# Image sauvegardée : images_output/1/image_758.png
# Image sauvegardée : images_output/1/image_759.png
# Image sauvegardée : images_output/1/image_760.png
# Image sauvegardée : images_output/1/image_761.png
# Image sauvegardée : images_output/1/image_762.png
# Image sauvegardée : images_output/1/image_763.png
# Image sauvegardée : images_output/1/image_764.png
# Image sauvegardée : images_output/1/image_765.png
# Image sauvegardée : images_output/1/image_766.png
# Image sauvegardée : images_output/1/image_767.png
# Image sauvegardée : images_output/1/image_768.png
# Image sauvegardée : images_output/1/image_769.png
# Image sauvegardée : images_output/1/image_770.png
# Image sauvegardée : images_output/1/image_771.png
# Image sauvegardée : images_output/1/image_772.png
# Image sauvegardée : images_output/1/image_773.png
# Image sauvegardée : images_output/1/image_774.png
# Image sauvegardée : images_output/1/image_775.png
# Image sauvegardée : images_output/1/image_776.png
# Image sauvegardée : images_output/1/image_777.png
# Image sauvegardée : images_output/1/image_778.png
# Image sauvegardée : images_output/1/image_779.png
# Image sauvegardée : images_output/1/image_780.png
# Image sauvegardée : images_output/1/image_781.png
# Image sauvegardée : images_output/1/image_782.png
# Image sauvegardée : images_output/1/image_783.png
# Image sauvegardée : images_output/1/image_784.png
# Image sauvegardée : images_output/1/image_785.png
# Image sauvegardée : images_output/1/image_786.png
# Image sauvegardée : images_output/1/image_787.png
# Image sauvegardée : images_output/1/image_788.png
# Image sauvegardée : images_output/1/image_789.png
# Image sauvegardée : images_output/1/image_790.png
# Image sauvegardée : images_output/1/image_791.png
# Image sauvegardée : images_output/1/image_792.png
# Image sauvegardée : images_output/1/image_793.png
# Image sauvegardée : images_output/1/image_794.png
# Image sauvegardée : images_output/1/image_795.png
# Image sauvegardée : images_output/1/image_796.png
# Image sauvegardée : images_output/1/image_797.png
# Image sauvegardée : images_output/1/image_798.png
# Image sauvegardée : images_output/1/image_799.png
# Image sauvegardée : images_output/1/image_800.png
# Image sauvegardée : images_output/1/image_801.png
# Image sauvegardée : images_output/1/image_802.png
# Image sauvegardée : images_output/1/image_803.png
# Image sauvegardée : images_output/1/image_804.png
# Image sauvegardée : images_output/1/image_805.png
# Image sauvegardée : images_output/1/image_806.png
# Image sauvegardée : images_output/1/image_807.png
# Image sauvegardée : images_output/1/image_808.png
# Image sauvegardée : images_output/1/image_809.png
# Image sauvegardée : images_output/1/image_810.png
# Image sauvegardée : images_output/1/image_811.png
# Image sauvegardée : images_output/1/image_812.png
# Image sauvegardée : images_output/1/image_813.png
# Image sauvegardée : images_output/1/image_814.png
# Image sauvegardée : images_output/1/image_815.png
# Image sauvegardée : images_output/1/image_816.png
# Image sauvegardée : images_output/1/image_817.png
# Image sauvegardée : images_output/1/image_818.png
# Image sauvegardée : images_output/1/image_819.png
# Image sauvegardée : images_output/1/image_820.png
# Image sauvegardée : images_output/1/image_821.png
# Image sauvegardée : images_output/1/image_822.png
# Image sauvegardée : images_output/1/image_823.png
# Image sauvegardée : images_output/1/image_824.png
# Image sauvegardée : images_output/1/image_825.png
# Image sauvegardée : images_output/1/image_826.png
# Image sauvegardée : images_output/1/image_827.png
# Image sauvegardée : images_output/1/image_828.png
# Image sauvegardée : images_output/1/image_829.png
# Image sauvegardée : images_output/1/image_830.png
# Image sauvegardée : images_output/1/image_831.png
# Image sauvegardée : images_output/1/image_832.png
# Image sauvegardée : images_output/1/image_833.png
# Image sauvegardée : images_output/1/image_834.png
# Image sauvegardée : images_output/1/image_835.png
# Image sauvegardée : images_output/1/image_836.png
# Image sauvegardée : images_output/1/image_837.png
# Image sauvegardée : images_output/1/image_838.png
# Image sauvegardée : images_output/1/image_839.png
# Image sauvegardée : images_output/1/image_840.png
# Image sauvegardée : images_output/1/image_841.png
# Image sauvegardée : images_output/1/image_842.png
# Image sauvegardée : images_output/1/image_843.png
# Image sauvegardée : images_output/1/image_844.png
# Image sauvegardée : images_output/1/image_845.png
# Image sauvegardée : images_output/1/image_846.png
# Image sauvegardée : images_output/1/image_847.png
# Image sauvegardée : images_output/1/image_848.png
# Image sauvegardée : images_output/1/image_849.png
# Image sauvegardée : images_output/1/image_850.png
# Image sauvegardée : images_output/1/image_851.png
# Image sauvegardée : images_output/1/image_852.png
# Image sauvegardée : images_output/1/image_853.png
# Image sauvegardée : images_output/1/image_854.png
# Image sauvegardée : images_output/1/image_855.png
# Image sauvegardée : images_output/1/image_856.png
# Image sauvegardée : images_output/1/image_857.png
# Image sauvegardée : images_output/1/image_858.png
# Image sauvegardée : images_output/1/image_859.png
# Image sauvegardée : images_output/1/image_860.png
# Image sauvegardée : images_output/1/image_861.png
# Image sauvegardée : images_output/1/image_862.png
# Image sauvegardée : images_output/1/image_863.png
# Image sauvegardée : images_output/1/image_864.png
# Image sauvegardée : images_output/1/image_865.png
# Image sauvegardée : images_output/1/image_866.png
# Image sauvegardée : images_output/1/image_867.png
# Image sauvegardée : images_output/1/image_868.png
# Image sauvegardée : images_output/1/image_869.png
# Image sauvegardée : images_output/1/image_870.png
# Image sauvegardée : images_output/1/image_871.png
# Image sauvegardée : images_output/1/image_872.png
# Image sauvegardée : images_output/1/image_873.png
# Image sauvegardée : images_output/1/image_874.png
# Image sauvegardée : images_output/1/image_875.png
# Image sauvegardée : images_output/1/image_876.png
# Image sauvegardée : images_output/1/image_877.png
# Image sauvegardée : images_output/1/image_878.png
# Image sauvegardée : images_output/1/image_879.png
# Image sauvegardée : images_output/1/image_880.png
# Image sauvegardée : images_output/1/image_881.png
# Image sauvegardée : images_output/1/image_882.png
# Image sauvegardée : images_output/1/image_883.png
# Image sauvegardée : images_output/1/image_884.png
# Image sauvegardée : images_output/1/image_885.png
# Image sauvegardée : images_output/1/image_886.png
# Image sauvegardée : images_output/1/image_887.png
# Image sauvegardée : images_output/1/image_888.png
# Image sauvegardée : images_output/1/image_889.png
# Image sauvegardée : images_output/1/image_890.png
# Image sauvegardée : images_output/1/image_891.png
# Image sauvegardée : images_output/1/image_892.png
# Image sauvegardée : images_output/1/image_893.png
# Image sauvegardée : images_output/1/image_894.png
# Image sauvegardée : images_output/1/image_895.png
# Image sauvegardée : images_output/1/image_896.png
# Image sauvegardée : images_output/1/image_897.png
# Image sauvegardée : images_output/1/image_898.png
# Image sauvegardée : images_output/1/image_899.png
# Image sauvegardée : images_output/1/image_900.png
# Image sauvegardée : images_output/1/image_901.png
# Image sauvegardée : images_output/1/image_902.png
# Image sauvegardée : images_output/1/image_903.png
# Image sauvegardée : images_output/1/image_904.png
# Image sauvegardée : images_output/1/image_905.png
# Image sauvegardée : images_output/1/image_906.png
# Image sauvegardée : images_output/1/image_907.png
# Image sauvegardée : images_output/1/image_908.png
# Image sauvegardée : images_output/1/image_909.png
# Image sauvegardée : images_output/1/image_910.png
# Image sauvegardée : images_output/1/image_911.png
# Image sauvegardée : images_output/1/image_912.png
# Image sauvegardée : images_output/1/image_913.png
# Image sauvegardée : images_output/1/image_914.png
# Image sauvegardée : images_output/1/image_915.png
# Image sauvegardée : images_output/1/image_916.png
# Image sauvegardée : images_output/1/image_917.png
# Image sauvegardée : images_output/1/image_918.png
# Image sauvegardée : images_output/1/image_919.png
# Image sauvegardée : images_output/1/image_920.png
# Image sauvegardée : images_output/1/image_921.png
# Image sauvegardée : images_output/1/image_922.png
# Image sauvegardée : images_output/1/image_923.png
# Image sauvegardée : images_output/1/image_924.png
# Image sauvegardée : images_output/1/image_925.png
# Image sauvegardée : images_output/1/image_926.png
# Image sauvegardée : images_output/1/image_927.png
# Image sauvegardée : images_output/1/image_928.png
# Image sauvegardée : images_output/1/image_929.png
# Image sauvegardée : images_output/1/image_930.png
# Image sauvegardée : images_output/1/image_931.png
# Image sauvegardée : images_output/1/image_932.png
# Image sauvegardée : images_output/1/image_933.png
# Image sauvegardée : images_output/1/image_934.png
# Image sauvegardée : images_output/1/image_935.png
# Image sauvegardée : images_output/1/image_936.png
# Image sauvegardée : images_output/1/image_937.png
# Image sauvegardée : images_output/1/image_938.png
# Image sauvegardée : images_output/1/image_939.png
# Image sauvegardée : images_output/1/image_940.png
# Image sauvegardée : images_output/1/image_941.png
# Image sauvegardée : images_output/1/image_942.png
# Image sauvegardée : images_output/1/image_943.png
# Image sauvegardée : images_output/1/image_944.png
# Image sauvegardée : images_output/1/image_945.png
# Image sauvegardée : images_output/1/image_946.png
# Image sauvegardée : images_output/1/image_947.png
# Image sauvegardée : images_output/1/image_948.png
# Image sauvegardée : images_output/1/image_949.png
# Image sauvegardée : images_output/1/image_950.png
# Image sauvegardée : images_output/1/image_951.png
# Image sauvegardée : images_output/1/image_952.png
# Image sauvegardée : images_output/1/image_953.png
# Image sauvegardée : images_output/1/image_954.png
# Image sauvegardée : images_output/1/image_955.png
# Image sauvegardée : images_output/1/image_956.png
# Image sauvegardée : images_output/1/image_957.png
# Image sauvegardée : images_output/1/image_958.png
# Image sauvegardée : images_output/1/image_959.png
# Image sauvegardée : images_output/1/image_960.png
# Image sauvegardée : images_output/1/image_961.png
# ...
# Image sauvegardée : images_output/1/image_1433.png
# Image sauvegardée : images_output/1/image_1434.png
# Image sauvegardée : images_output/1/image_1435.png
# Image sauvegardée : images_output/1/image_1436.png
# Image sauvegardée : images_output/1/image_1437.png
# Image sauvegardée : images_output/1/image_1438.png
# Image sauvegardée : images_output/1/image_1439.png
# Image sauvegardée : images_output/1/image_1440.png
# Image sauvegardée : images_output/1/image_1441.png
# Image sauvegardée : images_output/1/image_1442.png
# Image sauvegardée : images_output/1/image_1443.png
# Image sauvegardée : images_output/1/image_1444.png
# Image sauvegardée : images_output/1/image_1445.png
# Image sauvegardée : images_output/1/image_1446.png
# Image sauvegardée : images_output/1/image_1447.png
# Image sauvegardée : images_output/1/image_1448.png
# Image sauvegardée : images_output/1/image_1449.png
# Image sauvegardée : images_output/1/image_1450.png
# Image sauvegardée : images_output/1/image_1451.png
# Image sauvegardée : images_output/1/image_1452.png
# Image sauvegardée : images_output/1/image_1453.png
# Image sauvegardée : images_output/1/image_1454.png
# Image sauvegardée : images_output/1/image_1455.png
# Image sauvegardée : images_output/1/image_1456.png
# Image sauvegardée : images_output/1/image_1457.png
# Image sauvegardée : images_output/1/image_1458.png
# Image sauvegardée : images_output/1/image_1459.png
# Image sauvegardée : images_output/1/image_1460.png
# Image sauvegardée : images_output/1/image_1461.png
# Image sauvegardée : images_output/1/image_1462.png
# Image sauvegardée : images_output/1/image_1463.png
# Image sauvegardée : images_output/1/image_1464.png
# Image sauvegardée : images_output/1/image_1465.png
# Image sauvegardée : images_output/1/image_1466.png
# Image sauvegardée : images_output/1/image_1467.png
# Image sauvegardée : images_output/1/image_1468.png
# Image sauvegardée : images_output/1/image_1469.png
# Image sauvegardée : images_output/1/image_1470.png
# Image sauvegardée : images_output/1/image_1471.png
# Image sauvegardée : images_output/1/image_1472.png
# Image sauvegardée : images_output/1/image_1473.png
# Image sauvegardée : images_output/1/image_1474.png
# Image sauvegardée : images_output/1/image_1475.png
# Image sauvegardée : images_output/1/image_1476.png
# Image sauvegardée : images_output/1/image_1477.png
# Image sauvegardée : images_output/1/image_1478.png
# Image sauvegardée : images_output/1/image_1479.png
# Image sauvegardée : images_output/1/image_1480.png
# Image sauvegardée : images_output/1/image_1481.png
# Image sauvegardée : images_output/1/image_1482.png
# Image sauvegardée : images_output/1/image_1483.png
# Image sauvegardée : images_output/1/image_1484.png
# Image sauvegardée : images_output/1/image_1485.png
# Image sauvegardée : images_output/1/image_1486.png
# Image sauvegardée : images_output/1/image_1487.png
# Image sauvegardée : images_output/1/image_1488.png
# Image sauvegardée : images_output/1/image_1489.png
# Image sauvegardée : images_output/1/image_1490.png
# Image sauvegardée : images_output/1/image_1491.png
# Image sauvegardée : images_output/1/image_1492.png
# Image sauvegardée : images_output/1/image_1493.png
# Image sauvegardée : images_output/1/image_1494.png
# Image sauvegardée : images_output/1/image_1495.png
# Image sauvegardée : images_output/1/image_1496.png
# Image sauvegardée : images_output/1/image_1497.png
# Image sauvegardée : images_output/1/image_1498.png
# Image sauvegardée : images_output/1/image_1499.png
# Image sauvegardée : images_output/1/image_1500.png
# Image sauvegardée : images_output/1/image_1501.png
# Image sauvegardée : images_output/1/image_1502.png
# Image sauvegardée : images_output/1/image_1503.png
# Image sauvegardée : images_output/1/image_1504.png
# Image sauvegardée : images_output/1/image_1505.png
# Image sauvegardée : images_output/1/image_1506.png
# Image sauvegardée : images_output/1/image_1507.png
# Image sauvegardée : images_output/1/image_1508.png
# Image sauvegardée : images_output/1/image_1509.png
# Image sauvegardée : images_output/1/image_1510.png
# Image sauvegardée : images_output/1/image_1511.png
# Image sauvegardée : images_output/1/image_1512.png
# Image sauvegardée : images_output/1/image_1513.png
# Image sauvegardée : images_output/1/image_1514.png
# Image sauvegardée : images_output/1/image_1515.png
# Image sauvegardée : images_output/1/image_1516.png
# Image sauvegardée : images_output/1/image_1517.png
# Image sauvegardée : images_output/1/image_1518.png
# Image sauvegardée : images_output/1/image_1519.png
# Image sauvegardée : images_output/1/image_1520.png
# Image sauvegardée : images_output/1/image_1521.png
# Image sauvegardée : images_output/1/image_1522.png
# Image sauvegardée : images_output/1/image_1523.png
# Image sauvegardée : images_output/1/image_1524.png
# Image sauvegardée : images_output/1/image_1525.png
# Image sauvegardée : images_output/1/image_1526.png
# Image sauvegardée : images_output/1/image_1527.png
# Image sauvegardée : images_output/1/image_1528.png
# Image sauvegardée : images_output/1/image_1529.png
# Image sauvegardée : images_output/1/image_1530.png
# Image sauvegardée : images_output/1/image_1531.png
# Image sauvegardée : images_output/1/image_1532.png
# Image sauvegardée : images_output/1/image_1533.png
# Image sauvegardée : images_output/1/image_1534.png
# Image sauvegardée : images_output/1/image_1535.png
# Image sauvegardée : images_output/1/image_1536.png
# Image sauvegardée : images_output/1/image_1537.png
# Image sauvegardée : images_output/1/image_1538.png
# Image sauvegardée : images_output/1/image_1539.png
# Image sauvegardée : images_output/1/image_1540.png
# Image sauvegardée : images_output/1/image_1541.png
# Image sauvegardée : images_output/1/image_1542.png
# Image sauvegardée : images_output/1/image_1543.png
# Image sauvegardée : images_output/1/image_1544.png
# Image sauvegardée : images_output/1/image_1545.png
# Image sauvegardée : images_output/1/image_1546.png
# Image sauvegardée : images_output/1/image_1547.png
# Image sauvegardée : images_output/1/image_1548.png
# Image sauvegardée : images_output/1/image_1549.png
# Image sauvegardée : images_output/1/image_1550.png
# Image sauvegardée : images_output/1/image_1551.png
# Image sauvegardée : images_output/1/image_1552.png
# Image sauvegardée : images_output/1/image_1553.png
# Image sauvegardée : images_output/1/image_1554.png
# Image sauvegardée : images_output/1/image_1555.png
# Image sauvegardée : images_output/1/image_1556.png
# Image sauvegardée : images_output/1/image_1557.png
# Image sauvegardée : images_output/1/image_1558.png
# Image sauvegardée : images_output/1/image_1559.png
# Image sauvegardée : images_output/1/image_1560.png
# Image sauvegardée : images_output/1/image_1561.png
# Image sauvegardée : images_output/1/image_1562.png
# Image sauvegardée : images_output/1/image_1563.png
# Image sauvegardée : images_output/1/image_1564.png
# Image sauvegardée : images_output/1/image_1565.png
# Image sauvegardée : images_output/1/image_1566.png
# Image sauvegardée : images_output/1/image_1567.png
# Image sauvegardée : images_output/1/image_1568.png
# Image sauvegardée : images_output/1/image_1569.png
# Image sauvegardée : images_output/1/image_1570.png
# Image sauvegardée : images_output/1/image_1571.png
# Image sauvegardée : images_output/1/image_1572.png
# Image sauvegardée : images_output/1/image_1573.png
# Image sauvegardée : images_output/1/image_1574.png
# Image sauvegardée : images_output/1/image_1575.png
# Image sauvegardée : images_output/1/image_1576.png
# Image sauvegardée : images_output/1/image_1577.png
# Image sauvegardée : images_output/1/image_1578.png
# Image sauvegardée : images_output/1/image_1579.png
# Image sauvegardée : images_output/1/image_1580.png
# Image sauvegardée : images_output/1/image_1581.png
# Image sauvegardée : images_output/1/image_1582.png
# Image sauvegardée : images_output/1/image_1583.png
# Image sauvegardée : images_output/1/image_1584.png
# Image sauvegardée : images_output/1/image_1585.png
# Image sauvegardée : images_output/1/image_1586.png
# Image sauvegardée : images_output/1/image_1587.png
# Image sauvegardée : images_output/1/image_1588.png
# Image sauvegardée : images_output/1/image_1589.png
# Image sauvegardée : images_output/1/image_1590.png
# Image sauvegardée : images_output/1/image_1591.png
# Image sauvegardée : images_output/1/image_1592.png
# Image sauvegardée : images_output/1/image_1593.png
# Image sauvegardée : images_output/1/image_1594.png
# Image sauvegardée : images_output/1/image_1595.png
# Image sauvegardée : images_output/1/image_1596.png
# Image sauvegardée : images_output/1/image_1597.png
# Image sauvegardée : images_output/1/image_1598.png
# Image sauvegardée : images_output/1/image_1599.png
# Image sauvegardée : images_output/1/image_1600.png
# Image sauvegardée : images_output/1/image_1601.png
# Image sauvegardée : images_output/1/image_1602.png
# Image sauvegardée : images_output/1/image_1603.png
# Image sauvegardée : images_output/1/image_1604.png
# Image sauvegardée : images_output/1/image_1605.png
# Image sauvegardée : images_output/1/image_1606.png
# Image sauvegardée : images_output/1/image_1607.png
# Image sauvegardée : images_output/1/image_1608.png
# Image sauvegardée : images_output/1/image_1609.png
# Image sauvegardée : images_output/1/image_1610.png
# Image sauvegardée : images_output/1/image_1611.png
# Image sauvegardée : images_output/1/image_1612.png
# Image sauvegardée : images_output/1/image_1613.png
# Image sauvegardée : images_output/1/image_1614.png
# Image sauvegardée : images_output/1/image_1615.png
# Image sauvegardée : images_output/1/image_1616.png
# Image sauvegardée : images_output/1/image_1617.png
# Image sauvegardée : images_output/1/image_1618.png
# Image sauvegardée : images_output/1/image_1619.png
# Image sauvegardée : images_output/1/image_1620.png
# Image sauvegardée : images_output/1/image_1621.png
# Image sauvegardée : images_output/1/image_1622.png
# Image sauvegardée : images_output/1/image_1623.png
# Image sauvegardée : images_output/1/image_1624.png
# Image sauvegardée : images_output/1/image_1625.png
# Image sauvegardée : images_output/1/image_1626.png
# Image sauvegardée : images_output/1/image_1627.png
# Image sauvegardée : images_output/1/image_1628.png
# Image sauvegardée : images_output/1/image_1629.png
# Image sauvegardée : images_output/1/image_1630.png
# Image sauvegardée : images_output/1/image_1631.png
# Image sauvegardée : images_output/1/image_1632.png
# Image sauvegardée : images_output/1/image_1633.png
# Image sauvegardée : images_output/1/image_1634.png
# Image sauvegardée : images_output/1/image_1635.png
# Image sauvegardée : images_output/1/image_1636.png
# Image sauvegardée : images_output/1/image_1637.png
# Image sauvegardée : images_output/1/image_1638.png
# Image sauvegardée : images_output/1/image_1639.png
# Image sauvegardée : images_output/1/image_1640.png
# Image sauvegardée : images_output/1/image_1641.png
# Image sauvegardée : images_output/1/image_1642.png
# Image sauvegardée : images_output/1/image_1643.png
# Image sauvegardée : images_output/1/image_1644.png
# Image sauvegardée : images_output/1/image_1645.png
# Image sauvegardée : images_output/1/image_1646.png
# Image sauvegardée : images_output/1/image_1647.png
# Image sauvegardée : images_output/1/image_1648.png
# Image sauvegardée : images_output/1/image_1649.png
# Image sauvegardée : images_output/1/image_1650.png
# Image sauvegardée : images_output/1/image_1651.png
# Image sauvegardée : images_output/1/image_1652.png
# Image sauvegardée : images_output/1/image_1653.png
# Image sauvegardée : images_output/1/image_1654.png
# Image sauvegardée : images_output/1/image_1655.png
# Image sauvegardée : images_output/1/image_1656.png
# Image sauvegardée : images_output/1/image_1657.png
# Image sauvegardée : images_output/1/image_1658.png
# Image sauvegardée : images_output/1/image_1659.png
# Image sauvegardée : images_output/1/image_1660.png
# Image sauvegardée : images_output/1/image_1661.png
# Image sauvegardée : images_output/1/image_1662.png
# Image sauvegardée : images_output/1/image_1663.png
# Image sauvegardée : images_output/1/image_1664.png
# Image sauvegardée : images_output/1/image_1665.png
# Image sauvegardée : images_output/1/image_1666.png
# Image sauvegardée : images_output/1/image_1667.png
# Image sauvegardée : images_output/1/image_1668.png
# Image sauvegardée : images_output/1/image_1669.png
# Image sauvegardée : images_output/1/image_1670.png
# Image sauvegardée : images_output/1/image_1671.png
# Image sauvegardée : images_output/1/image_1672.png
# Image sauvegardée : images_output/1/image_1673.png
# Image sauvegardée : images_output/1/image_1674.png
# Image sauvegardée : images_output/1/image_1675.png
# Image sauvegardée : images_output/1/image_1676.png
# Image sauvegardée : images_output/1/image_1677.png
# Image sauvegardée : images_output/1/image_1678.png
# Image sauvegardée : images_output/1/image_1679.png
# Image sauvegardée : images_output/1/image_1680.png
# Image sauvegardée : images_output/1/image_1681.png
# Image sauvegardée : images_output/1/image_1682.png
# Image sauvegardée : images_output/1/image_1683.png
# Image sauvegardée : images_output/1/image_1684.png
# Image sauvegardée : images_output/1/image_1685.png
# Image sauvegardée : images_output/1/image_1686.png
# Image sauvegardée : images_output/1/image_1687.png
# Image sauvegardée : images_output/1/image_1688.png
# Image sauvegardée : images_output/1/image_1689.png
# Image sauvegardée : images_output/1/image_1690.png
# Image sauvegardée : images_output/1/image_1691.png
# Image sauvegardée : images_output/1/image_1692.png
# Image sauvegardée : images_output/1/image_1693.png
# Image sauvegardée : images_output/1/image_1694.png
# Image sauvegardée : images_output/1/image_1695.png
# Image sauvegardée : images_output/1/image_1696.png
# Image sauvegardée : images_output/1/image_1697.png
# Image sauvegardée : images_output/1/image_1698.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:554, in _save(im, fp, tile, bufsize)
#     553 try:
# --> 554     fh = fp.fileno()
#     555     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 21
#      19     # Ouvrir l'image et la sauvegarder
#      20     image = Image.open(io.BytesIO(image_data))
# ---> 21     image.save(file_path, format="PNG")
#      22     print(f"Image sauvegardée : {file_path}")
#      23 except Exception as e:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/Image.py:2605, in Image.save(self, fp, format, **params)
#    2602     fp = cast(IO[bytes], fp)
#    2604 try:
# -> 2605     save_handler(self, fp, filename)
#    2606 except Exception:
#    2607     if open_fp:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1488, in _save(im, fp, filename, chunk, save_all)
#    1484     single_im = _write_multiple_frames(
#    1485         im, fp, chunk, mode, rawmode, default_image, append_images
#    1486     )
#    1487 if single_im:
# -> 1488     ImageFile._save(
#    1489         single_im,
#    1490         cast(IO[bytes], _idat(fp, chunk)),
#    1491         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1492     )
#    1494 if info:
#    1495     for info_chunk in info.chunks:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:558, in _save(im, fp, tile, bufsize)
#     556     _encode_tile(im, fp, tile, bufsize, fh)
#     557 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 558     _encode_tile(im, fp, tile, bufsize, None, exc)
#     559 if hasattr(fp, "flush"):
#     560     fp.flush()
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:584, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     581 if exc:
#     582     # compress to Python file-compatible object
#     583     while True:
# --> 584         errcode, data = encoder.encode(bufsize)[1:]
#     585         fp.write(data)
#     586         if errcode:
#
# KeyboardInterrupt:

# %%
output_dir = "images_output/2/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
for index, row in df2.iterrows():
    # Récupérer l'image encodée (Base64 ou bytes)
    image_data = row['image']['bytes']
    
    # Créer un nom de fichier basé sur l'index ou une autre colonne
    file_name = f"image_{index}.png"
    file_path = os.path.join(output_dir, file_name)

    try:
        # Si l'image est encodée en Base64, la décoder
        if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
            image_data = base64.b64decode(image_data)
        
        # Ouvrir l'image et la sauvegarder
        image = Image.open(io.BytesIO(image_data))
        image.save(file_path, format="PNG")
        print(f"Image sauvegardée : {file_path}")
    except Exception as e:
        print(f"Erreur pour l'index {index}: {e}")

# %%
output_dir = "images_output/3/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
for index, row in df3.iterrows():
    # Récupérer l'image encodée (Base64 ou bytes)
    image_data = row['image']['bytes']
    
    # Créer un nom de fichier basé sur l'index ou une autre colonne
    file_name = f"image_{index}.png"
    file_path = os.path.join(output_dir, file_name)

    try:
        # Si l'image est encodée en Base64, la décoder
        if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
            image_data = base64.b64decode(image_data)
        
        # Ouvrir l'image et la sauvegarder
        image = Image.open(io.BytesIO(image_data))
        image.save(file_path, format="PNG")
        print(f"Image sauvegardée : {file_path}")
    except Exception as e:
        print(f"Erreur pour l'index {index}: {e}")

# %%
# output_dir = "images_output"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# for i, df in enumerate(dataframes):
#     # Créer un sous-dossier pour chaque DataFrame
#     sub_dir = os.path.join(output_dir, f"df_{i+1}")
#     os.makedirs(sub_dir, exist_ok=True)
    
#     for index, row in df.iterrows():
#         # Récupérer l'image encodée (Base64 ou bytes)
#         image_data = row['image']['bytes']  # Assurez-vous que 'image' est une colonne contenant un dict avec 'bytes'

#         # Créer un nom de fichier basé sur l'index ou une autre colonne
#         file_name = f"image_{index}.png"
#         file_path = os.path.join(sub_dir, file_name)

#         try:
#             # Si l'image est encodée en Base64, la décoder
#             if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
#                 image_data = base64.b64decode(image_data)

#             # Ouvrir l'image et la sauvegarder
#             image = Image.open(io.BytesIO(image_data))
#             image.save(file_path, format="PNG")
#             print(f"Image sauvegardée dans {file_path}")
#         except Exception as e:
#             print(f"Erreur pour l'index {index} dans df_{i+1}: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       7 sub_dir = os.path.join(output_dir, f"df_{i+1}")
#       8 os.makedirs(sub_dir, exist_ok=True)
# ---> 10 for index, row in df.iterrows():
#      11     # Récupérer l'image encodée (Base64 ou bytes)
#      12     image_data = row['image']['bytes']  # Assurez-vous que 'image' est une colonne contenant un dict avec 'bytes'
#      14     # Créer un nom de fichier basé sur l'index ou une autre colonne
#
# AttributeError: 'str' object has no attribute 'iterrows'
