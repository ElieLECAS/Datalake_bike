# %%
import os
import base64
from PIL import Image
import io
import pandas as pd
import os

# Chemin du dossier contenant les fichiers Parquet
input_dir = "downloads/product_eval/"

# Dictionnaire pour stocker les DataFrames
dataframes = {}

# Parcourir tous les fichiers dans le dossier
for i, file_name in enumerate(os.listdir(input_dir), start=1):
    count = 1
    if file_name.endswith(".parquet"):
        file_path = os.path.join(input_dir, file_name)
        print(f"Chargement du fichier : {file_path}")
        
        # Charger le fichier Parquet
        df = pd.read_parquet(file_path)

        # Ajouter le DataFrame au dictionnaire avec un nom dynamique
        dataframes[f"df{i}"] = df
# Out:
# Chargement du fichier : downloads/product_eval/test-00001-of-00003.parquet
# Chargement du fichier : downloads/product_eval/test-00002-of-00003.parquet
# Chargement du fichier : downloads/product_eval/test-00000-of-00003.parquet

# %%
df1 = dataframes["df1"]
df1
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFF\x9c;\x00\x00WEBPVP8 \x90;\x00...  id-B00O4AJHGA  None
# 1      {'bytes': b'RIFF\xae.\x00\x00WEBPVP8 \xa2.\x00...  id-B00O4CVNHE  None
# 2      {'bytes': b'RIFF\xd2\x19\x00\x00WEBPVP8 \xc6\x...  id-B00O4DGXDM  None
# 3      {'bytes': b'RIFFv\x1f\x00\x00WEBPVP8 j\x1f\x00...  id-B00O4DJEO2  None
# 4      {'bytes': b'RIFF\x96\x05\x00\x00WEBPVP8 \x8a\x...  id-B00O4EUUP8  None
# ...                                                  ...            ...   ...
# 33328  {'bytes': b'RIFF\xf86\x00\x00WEBPVP8 \xec6\x00...  id-B07Q92SY6D  None
# 33329  {'bytes': b'RIFFT.\x00\x00WEBPVP8 H.\x00\x00\x...  id-B07Q93CYWQ  None
# 33330  {'bytes': b'RIFF\x10\x1f\x00\x00WEBPVP8 \x04\x...  id-B07Q98DRK5  None
# 33331  {'bytes': b'RIFF\x8a[\x00\x00WEBPVP8 ~[\x00\x0...  id-B07Q9HTZMP  None
# 33332  {'bytes': b'RIFF\x98\x0b\x00\x00WEBPVP8 \x8c\x...  id-B07Q9J3FVQ  None
#
#                                                    title  position
# 0                                             Dr Who:076         0
# 1                                    Faust (Illustrated)         0
# 2      TowelSelections Men's Robe, Turkish Cotton Kim...         0
# 3      CafePress I SCRUB ST Stainless Steel Travel Mu...         0
# 4      5/6 Year Old Fully Pinnable Child Dress Form M...         0
# ...                                                  ...       ...
# 33328  SANDALUP Flat Sandals for Women Summer Beach S...         0
# 33329  S.H.Figuarts Action Figure Iron Man Mark 3 Abo...         0
# 33330  MEETCCY Original 925 Sterling Silver Red Ename...         0
# 33331  Sousuoty Batwing Sleeve Tops for Women Loose F...         0
# 33332  Chargances Black Suede Moon Crescent Choker Bo...         0
#
# [33333 rows x 5 columns]

# %%
df2 = dataframes["df2"]
df2
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFFXV\x00\x00WEBPVP8 LV\x00\x00P\...  id-B07Q9J7JTW  None
# 1      {'bytes': b'RIFF\x8e\x1d\x00\x00WEBPVP8 \x82\x...  id-B07Q9LD5CF  None
# 2      {'bytes': b'RIFF\xd0#\x00\x00WEBPVP8 \xc4#\x00...  id-B07Q9LH8SP  None
# 3      {'bytes': b'RIFF\xbcX\x00\x00WEBPVP8 \xb0X\x00...  id-B07Q9LJ7TJ  None
# 4      {'bytes': b'RIFF\xa4\\\x00\x00WEBPVP8 \x98\\\x...  id-B07Q9LJBVF  None
# ...                                                  ...            ...   ...
# 33328  {'bytes': b'RIFF\xd2\x18\x00\x00WEBPVP8 \xc6\x...  id-B0CKMPX4S1  None
# 33329  {'bytes': b'RIFFB\x1c\x00\x00WEBPVP8 6\x1c\x00...  id-B0CKR2W4NZ  None
# 33330  {'bytes': b'RIFF\xd6\x1d\x00\x00WEBPVP8 \xca\x...  id-B0CKSG3K3N  None
# 33331  {'bytes': b'RIFF$\'\x00\x00WEBPVP8 \x18\'\x00\...  id-B0CKSR5VMV  None
# 33332  {'bytes': b'RIFF\xa2,\x00\x00WEBPVP8 \x96,\x00...  id-B0CKWTP4F5  None
#
#                                                    title  position
# 0      172 Pcs Zipper Replacement Zipper Repair Kit Z...         0
# 1      DWCN Total Privacy Room Divider Blackout Curta...         0
# 2      Benificer Pull Up Bar Set - 3 in 1 Doorway Chi...         0
# 3                 EverOne Survival First Aid Kit - Black         0
# 4      LEINASEN Little Kids Girl's Beach Crochet Mesh...         0
# ...                                                  ...       ...
# 33328  adidas Women's Itavic 3-Stripes Midweight Hood...         0
# 33329  BETHZA Diamond Pearl Necklace for Women Sterli...         0
# 33330  POWEART 30Kpa Cordless Vacuum Cleaner, 8-in-1 ...         0
# 33331  Rain Cloud Humidifier Water Drip, 2 in 1 Humid...         0
# 33332  Sensationnel X-pression prestretched braiding ...         0
#
# [33333 rows x 5 columns]

# %%
df3 = dataframes["df3"]
df3
# Out:
#                                                    image        item_ID query  \
# 0      {'bytes': b'RIFF~\x1e\x00\x00WEBPVP8 r\x1e\x00...  id-0002216949  None
# 1      {'bytes': b'RIFF:\x13\x00\x00WEBPVP8 .\x13\x00...  id-0006128513  None
# 2      {'bytes': b'RIFF\x1a\x1e\x00\x00WEBPVP8 \x0e\x...  id-0006338658  None
# 3      {'bytes': b'RIFF\xb2r\x00\x00WEBPVP8 \xa6r\x00...  id-0006483682  None
# 4      {'bytes': b'RIFFN\'\x00\x00WEBPVP8 B\'\x00\x00...  id-0006511252  None
# ...                                                  ...            ...   ...
# 33329  {'bytes': b'RIFF\x04U\x00\x00WEBPVP8 \xf8T\x00...  id-B00O40V55G  None
# 33330  {'bytes': b'RIFF>.\x00\x00WEBPVP8 2.\x00\x00\x...  id-B00O45QD8K  None
# 33331  {'bytes': b'RIFF"\x15\x00\x00WEBPVP8 \x16\x15\...  id-B00O46PUMY  None
# 33332  {'bytes': b'RIFF&\x10\x00\x00WEBPVP8 \x1a\x10\...  id-B00O472MO2  None
# 33333  {'bytes': b'RIFF \x11\x00\x00WEBPVP8 \x14\x11\...  id-B00O4A6PTW  None
#
#                                                    title  position
# 0                                                 Ransom         0
# 1                                    Caravan to Vaccares         0
# 2      Chronicles of Wasted Time: The Infernal Grove ...         0
# 3                                           Dragonshadow         0
# 4      Flashman (The Flashman Papers, Book 1) (The Fl...         0
# ...                                                  ...       ...
# 33329  Pathfinder Adventure Card Game: Skull & Shackl...         0
# 33330           Maxpedition Proteus Versipack Waist Pack         0
# 33331  Westcott Kids Non-Stick Scissors, Blunt, 5", C...         0
# 33332  Kaufhof KSP15 Woodworking Table Saw Safety Pus...         0
# 33333  it luggage Mega lite Luggage Spinner Collectio...         0
#
# [33334 rows x 5 columns]

# %%
# Chemin de sortie pour enregistrer les images
output_dir = "images_output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
for index, row in df1.iterrows():
    # Récupérer l'image encodée (Base64 ou bytes)
    image_data = row['image']['bytes']
    
    # Créer un nom de fichier basé sur l'index ou une autre colonne
    file_name = f"image_{index}.png"
    file_path = os.path.join(output_dir, file_name)

    try:
        # Si l'image est encodée en Base64, la décoder
        if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
            image_data = base64.b64decode(image_data)
        
        # Ouvrir l'image et la sauvegarder
        image = Image.open(io.BytesIO(image_data))
        image.save(file_path, format="PNG")
        print(f"Image sauvegardée : {file_path}")
    except Exception as e:
        print(f"Erreur pour l'index {index}: {e}")
# Out:
# Image sauvegardée : images_output/image_0.png
# Image sauvegardée : images_output/image_1.png
# Image sauvegardée : images_output/image_2.png
# Image sauvegardée : images_output/image_3.png
# Image sauvegardée : images_output/image_4.png
# Image sauvegardée : images_output/image_5.png
# Image sauvegardée : images_output/image_6.png
# Image sauvegardée : images_output/image_7.png
# Image sauvegardée : images_output/image_8.png
# Image sauvegardée : images_output/image_9.png
# Image sauvegardée : images_output/image_10.png
# Image sauvegardée : images_output/image_11.png
# Image sauvegardée : images_output/image_12.png
# Image sauvegardée : images_output/image_13.png
# Image sauvegardée : images_output/image_14.png
# Image sauvegardée : images_output/image_15.png
# Image sauvegardée : images_output/image_16.png
# Image sauvegardée : images_output/image_17.png
# Image sauvegardée : images_output/image_18.png
# Image sauvegardée : images_output/image_19.png
# Image sauvegardée : images_output/image_20.png
# Image sauvegardée : images_output/image_21.png
# Image sauvegardée : images_output/image_22.png
# Image sauvegardée : images_output/image_23.png
# Image sauvegardée : images_output/image_24.png
# Image sauvegardée : images_output/image_25.png
# Image sauvegardée : images_output/image_26.png
# Image sauvegardée : images_output/image_27.png
# Image sauvegardée : images_output/image_28.png
# Image sauvegardée : images_output/image_29.png
# Image sauvegardée : images_output/image_30.png
# Image sauvegardée : images_output/image_31.png
# Image sauvegardée : images_output/image_32.png
# Image sauvegardée : images_output/image_33.png
# Image sauvegardée : images_output/image_34.png
# Image sauvegardée : images_output/image_182.png
# Image sauvegardée : images_output/image_183.png
# Image sauvegardée : images_output/image_184.png
# Image sauvegardée : images_output/image_185.png
# Image sauvegardée : images_output/image_186.png
# Image sauvegardée : images_output/image_187.png
# Image sauvegardée : images_output/image_188.png
# Image sauvegardée : images_output/image_189.png
# Image sauvegardée : images_output/image_190.png
# Image sauvegardée : images_output/image_191.png
# Image sauvegardée : images_output/image_192.png
# Image sauvegardée : images_output/image_193.png
# Image sauvegardée : images_output/image_194.png
# Image sauvegardée : images_output/image_195.png
# Image sauvegardée : images_output/image_196.png
# Image sauvegardée : images_output/image_197.png
# Image sauvegardée : images_output/image_198.png
# Image sauvegardée : images_output/image_199.png
# Image sauvegardée : images_output/image_200.png
# Image sauvegardée : images_output/image_201.png
# Image sauvegardée : images_output/image_202.png
# Image sauvegardée : images_output/image_203.png
# Image sauvegardée : images_output/image_204.png
# Image sauvegardée : images_output/image_205.png
# Image sauvegardée : images_output/image_206.png
# Image sauvegardée : images_output/image_207.png
# Image sauvegardée : images_output/image_208.png
# Image sauvegardée : images_output/image_209.png
# Image sauvegardée : images_output/image_210.png
# Image sauvegardée : images_output/image_211.png
# Image sauvegardée : images_output/image_212.png
# Image sauvegardée : images_output/image_213.png
# Image sauvegardée : images_output/image_214.png
# Image sauvegardée : images_output/image_215.png
# Image sauvegardée : images_output/image_216.png
# Image sauvegardée : images_output/image_217.png
# Image sauvegardée : images_output/image_218.png
# Image sauvegardée : images_output/image_219.png
# Image sauvegardée : images_output/image_220.png
# Image sauvegardée : images_output/image_221.png
# Image sauvegardée : images_output/image_222.png
# Image sauvegardée : images_output/image_223.png
# Image sauvegardée : images_output/image_224.png
# Image sauvegardée : images_output/image_225.png
# Image sauvegardée : images_output/image_226.png
# Image sauvegardée : images_output/image_227.png
# Image sauvegardée : images_output/image_228.png
# Image sauvegardée : images_output/image_229.png
# Image sauvegardée : images_output/image_230.png
# Image sauvegardée : images_output/image_231.png
# Image sauvegardée : images_output/image_232.png
# Image sauvegardée : images_output/image_233.png
# Image sauvegardée : images_output/image_234.png
# Image sauvegardée : images_output/image_235.png
# Image sauvegardée : images_output/image_236.png
# Image sauvegardée : images_output/image_237.png
# Image sauvegardée : images_output/image_238.png
# Image sauvegardée : images_output/image_239.png
# Image sauvegardée : images_output/image_240.png
# Image sauvegardée : images_output/image_241.png
# Image sauvegardée : images_output/image_242.png
# Image sauvegardée : images_output/image_243.png
# Image sauvegardée : images_output/image_244.png
# Image sauvegardée : images_output/image_245.png
# Image sauvegardée : images_output/image_246.png
# Image sauvegardée : images_output/image_247.png
# Image sauvegardée : images_output/image_248.png
# Image sauvegardée : images_output/image_249.png
# Image sauvegardée : images_output/image_250.png
# Image sauvegardée : images_output/image_251.png
# Image sauvegardée : images_output/image_252.png
# Image sauvegardée : images_output/image_253.png
# Image sauvegardée : images_output/image_254.png
# Image sauvegardée : images_output/image_255.png
# Image sauvegardée : images_output/image_256.png
# Image sauvegardée : images_output/image_257.png
# Image sauvegardée : images_output/image_258.png
# Image sauvegardée : images_output/image_259.png
# Image sauvegardée : images_output/image_260.png
# Image sauvegardée : images_output/image_261.png
# Image sauvegardée : images_output/image_262.png
# Image sauvegardée : images_output/image_263.png
# Image sauvegardée : images_output/image_264.png
# Image sauvegardée : images_output/image_265.png
# Image sauvegardée : images_output/image_266.png
# Image sauvegardée : images_output/image_267.png
# Image sauvegardée : images_output/image_268.png
# Image sauvegardée : images_output/image_269.png
# Image sauvegardée : images_output/image_270.png
# Image sauvegardée : images_output/image_271.png
# Image sauvegardée : images_output/image_272.png
# Image sauvegardée : images_output/image_273.png
# Image sauvegardée : images_output/image_274.png
# Image sauvegardée : images_output/image_275.png
# Image sauvegardée : images_output/image_276.png
# Image sauvegardée : images_output/image_277.png
# Image sauvegardée : images_output/image_278.png
# Image sauvegardée : images_output/image_279.png
# Image sauvegardée : images_output/image_280.png
# Image sauvegardée : images_output/image_281.png
# Image sauvegardée : images_output/image_282.png
# Image sauvegardée : images_output/image_283.png
# Image sauvegardée : images_output/image_284.png
# Image sauvegardée : images_output/image_285.png
# Image sauvegardée : images_output/image_286.png
# Image sauvegardée : images_output/image_287.png
# Image sauvegardée : images_output/image_288.png
# Image sauvegardée : images_output/image_289.png
# Image sauvegardée : images_output/image_290.png
# Image sauvegardée : images_output/image_291.png
# Image sauvegardée : images_output/image_292.png
# Image sauvegardée : images_output/image_293.png
# Image sauvegardée : images_output/image_294.png
# Image sauvegardée : images_output/image_295.png
# Image sauvegardée : images_output/image_296.png
# Image sauvegardée : images_output/image_297.png
# Image sauvegardée : images_output/image_298.png
# Image sauvegardée : images_output/image_299.png
# Image sauvegardée : images_output/image_300.png
# Image sauvegardée : images_output/image_301.png
# Image sauvegardée : images_output/image_302.png
# Image sauvegardée : images_output/image_303.png
# Image sauvegardée : images_output/image_304.png
# Image sauvegardée : images_output/image_305.png
# Image sauvegardée : images_output/image_306.png
# Image sauvegardée : images_output/image_307.png
# Image sauvegardée : images_output/image_308.png
# Image sauvegardée : images_output/image_309.png
# Image sauvegardée : images_output/image_310.png
# Image sauvegardée : images_output/image_311.png
# Image sauvegardée : images_output/image_312.png
# Image sauvegardée : images_output/image_313.png
# Image sauvegardée : images_output/image_314.png
# Image sauvegardée : images_output/image_315.png
# Image sauvegardée : images_output/image_316.png
# Image sauvegardée : images_output/image_317.png
# Image sauvegardée : images_output/image_318.png
# Image sauvegardée : images_output/image_319.png
# Image sauvegardée : images_output/image_320.png
# Image sauvegardée : images_output/image_321.png
# Image sauvegardée : images_output/image_322.png
# Image sauvegardée : images_output/image_323.png
# Image sauvegardée : images_output/image_324.png
# Image sauvegardée : images_output/image_325.png
# Image sauvegardée : images_output/image_326.png
# Image sauvegardée : images_output/image_327.png
# Image sauvegardée : images_output/image_328.png
# Image sauvegardée : images_output/image_329.png
# Image sauvegardée : images_output/image_330.png
# Image sauvegardée : images_output/image_331.png
# Image sauvegardée : images_output/image_332.png
# Image sauvegardée : images_output/image_333.png
# Image sauvegardée : images_output/image_334.png
# Image sauvegardée : images_output/image_335.png
# Image sauvegardée : images_output/image_336.png
# Image sauvegardée : images_output/image_337.png
# Image sauvegardée : images_output/image_338.png
# Image sauvegardée : images_output/image_339.png
# Image sauvegardée : images_output/image_340.png
# Image sauvegardée : images_output/image_341.png
# Image sauvegardée : images_output/image_342.png
# Image sauvegardée : images_output/image_343.png
# Image sauvegardée : images_output/image_344.png
# Image sauvegardée : images_output/image_345.png
# Image sauvegardée : images_output/image_346.png
# Image sauvegardée : images_output/image_347.png
# Image sauvegardée : images_output/image_348.png
# Image sauvegardée : images_output/image_349.png
# Image sauvegardée : images_output/image_350.png
# Image sauvegardée : images_output/image_351.png
# Image sauvegardée : images_output/image_352.png
# Image sauvegardée : images_output/image_353.png
# Image sauvegardée : images_output/image_354.png
# Image sauvegardée : images_output/image_355.png
# Image sauvegardée : images_output/image_356.png
# Image sauvegardée : images_output/image_357.png
# Image sauvegardée : images_output/image_358.png
# Image sauvegardée : images_output/image_359.png
# Image sauvegardée : images_output/image_360.png
# Image sauvegardée : images_output/image_361.png
# Image sauvegardée : images_output/image_362.png
# Image sauvegardée : images_output/image_363.png
# Image sauvegardée : images_output/image_364.png
# Image sauvegardée : images_output/image_365.png
# Image sauvegardée : images_output/image_366.png
# Image sauvegardée : images_output/image_367.png
# Image sauvegardée : images_output/image_368.png
# Image sauvegardée : images_output/image_369.png
# Image sauvegardée : images_output/image_370.png
# Image sauvegardée : images_output/image_371.png
# Image sauvegardée : images_output/image_372.png
# Image sauvegardée : images_output/image_373.png
# Image sauvegardée : images_output/image_374.png
# Image sauvegardée : images_output/image_375.png
# Image sauvegardée : images_output/image_376.png
# Image sauvegardée : images_output/image_377.png
# Image sauvegardée : images_output/image_378.png
# Image sauvegardée : images_output/image_379.png
# Image sauvegardée : images_output/image_380.png
# Image sauvegardée : images_output/image_381.png
# Image sauvegardée : images_output/image_382.png
# Image sauvegardée : images_output/image_383.png
# Image sauvegardée : images_output/image_384.png
# Image sauvegardée : images_output/image_385.png
# Image sauvegardée : images_output/image_386.png
# Image sauvegardée : images_output/image_387.png
# Image sauvegardée : images_output/image_388.png
# Image sauvegardée : images_output/image_389.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:554, in _save(im, fp, tile, bufsize)
#     553 try:
# --> 554     fh = fp.fileno()
#     555     fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 21
#      19     # Ouvrir l'image et la sauvegarder
#      20     image = Image.open(io.BytesIO(image_data))
# ---> 21     image.save(file_path, format="PNG")
#      22     print(f"Image sauvegardée : {file_path}")
#      23 except Exception as e:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/Image.py:2605, in Image.save(self, fp, format, **params)
#    2602     fp = cast(IO[bytes], fp)
#    2604 try:
# -> 2605     save_handler(self, fp, filename)
#    2606 except Exception:
#    2607     if open_fp:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/PngImagePlugin.py:1488, in _save(im, fp, filename, chunk, save_all)
#    1484     single_im = _write_multiple_frames(
#    1485         im, fp, chunk, mode, rawmode, default_image, append_images
#    1486     )
#    1487 if single_im:
# -> 1488     ImageFile._save(
#    1489         single_im,
#    1490         cast(IO[bytes], _idat(fp, chunk)),
#    1491         [ImageFile._Tile("zip", (0, 0) + single_im.size, 0, rawmode)],
#    1492     )
#    1494 if info:
#    1495     for info_chunk in info.chunks:
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:558, in _save(im, fp, tile, bufsize)
#     556     _encode_tile(im, fp, tile, bufsize, fh)
#     557 except (AttributeError, io.UnsupportedOperation) as exc:
# --> 558     _encode_tile(im, fp, tile, bufsize, None, exc)
#     559 if hasattr(fp, "flush"):
#     560     fp.flush()
#
# File ~/Documents/Code/Briefs/Datalake_bike/venv/lib/python3.12/site-packages/PIL/ImageFile.py:584, in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     581 if exc:
#     582     # compress to Python file-compatible object
#     583     while True:
# --> 584         errcode, data = encoder.encode(bufsize)[1:]
#     585         fp.write(data)
#     586         if errcode:
#
# KeyboardInterrupt:

# %%
# output_dir = "images_output"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# for i, df in enumerate(dataframes):
#     # Créer un sous-dossier pour chaque DataFrame
#     sub_dir = os.path.join(output_dir, f"df_{i+1}")
#     os.makedirs(sub_dir, exist_ok=True)
    
#     for index, row in df.iterrows():
#         # Récupérer l'image encodée (Base64 ou bytes)
#         image_data = row['image']['bytes']  # Assurez-vous que 'image' est une colonne contenant un dict avec 'bytes'

#         # Créer un nom de fichier basé sur l'index ou une autre colonne
#         file_name = f"image_{index}.png"
#         file_path = os.path.join(sub_dir, file_name)

#         try:
#             # Si l'image est encodée en Base64, la décoder
#             if isinstance(image_data, str):  # Vérifie si l'image est encodée en base64
#                 image_data = base64.b64decode(image_data)

#             # Ouvrir l'image et la sauvegarder
#             image = Image.open(io.BytesIO(image_data))
#             image.save(file_path, format="PNG")
#             print(f"Image sauvegardée dans {file_path}")
#         except Exception as e:
#             print(f"Erreur pour l'index {index} dans df_{i+1}: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       7 sub_dir = os.path.join(output_dir, f"df_{i+1}")
#       8 os.makedirs(sub_dir, exist_ok=True)
# ---> 10 for index, row in df.iterrows():
#      11     # Récupérer l'image encodée (Base64 ou bytes)
#      12     image_data = row['image']['bytes']  # Assurez-vous que 'image' est une colonne contenant un dict avec 'bytes'
#      14     # Créer un nom de fichier basé sur l'index ou une autre colonne
#
# AttributeError: 'str' object has no attribute 'iterrows'
