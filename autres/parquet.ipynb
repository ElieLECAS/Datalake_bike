# %%
from azure.storage.blob import BlobServiceClient, generate_blob_sas, BlobSasPermissions
from datetime import datetime, timedelta
import os

# Informations de base
account_name = "datalakedeviavals"
account_key = "Di7GZT/MHmRkRD6UTcIZmjnuWWhye/yvN2nFUTrgP380meAg4ggupT8RBGmL3IFnoI6aTqam3WFe+AStF56q9g=="
container_name = "datalakedeviavals"
blob_name = "data"

# Durée de validité du SAS
expiry_time = datetime.utcnow() + timedelta(hours=1)  # Expire dans 1 heure

# Permissions SAS
permissions = BlobSasPermissions(read=True, write=True, delete=True, list=True)

# Génération du SAS
sas_token = generate_blob_sas(
    account_name=account_name,
    container_name=container_name,
    blob_name=blob_name,  # Supprimez cette ligne si vous générez un SAS pour un conteneur
    account_key=account_key,
    permission=permissions,
    expiry=expiry_time
)

# URL avec SAS
blob_url_with_sas = f"https://{account_name}.blob.core.windows.net/{container_name}/{blob_name}?{sas_token}"

# Résultat
print("SAS Token:", sas_token)
print("Blob URL with SAS:", blob_url_with_sas)
# Out:
# SAS Token: se=2024-11-26T11%3A00%3A41Z&sp=rwd&sv=2025-01-05&sr=b&sig=rTl81kTsclUqqtiNQ70Kv8c0DMAarMJ3p07K2W3swy4%3D
# Blob URL with SAS: https://datalakedeviavals.blob.core.windows.net/datalakedeviavals/data?se=2024-11-26T11%3A00%3A41Z&sp=rwd&sv=2025-01-05&sr=b&sig=rTl81kTsclUqqtiNQ70Kv8c0DMAarMJ3p07K2W3swy4%3D
# /tmp/ipykernel_16596/2272394446.py:12: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   expiry_time = datetime.utcnow() + timedelta(hours=1)  # Expire dans 1 heure

# %%
# Remplacez par vos informations
account_name = "datalakedeviavals"
container_name = "data"

# Créer une connexion BlobServiceClient
blob_service_client = BlobServiceClient(
    f"https://{account_name}.blob.core.windows.net",
    credential=account_key
)

# Accéder à un conteneur
container_client = blob_service_client.get_container_client(container_name)

print(f"Connexion réussie au conteneur {container_name}.")

# Liste des blobs (fichiers) dans le conteneur
print("Blobs disponibles :")
for blob in container_client.list_blobs():
    print(blob.name)
# Out:
# Connexion réussie au conteneur data.
# Blobs disponibles :
# machine_learning
# machine_learning/reviews.zip
# nlp_data
# nlp_data/amazon-product-reviews
# nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.xlsx
# nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.xlsx
# nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.xlsx
# nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.xlsx
# nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.xlsx
# nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.csv
# nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.xlsx
# nlp_data/app-store-reviews
# nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.csv
# nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.xlsx
# nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.csv
# nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.xlsx
# nlp_data/etsy-reviews
# nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv
# nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx
# nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv
# nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx
# nlp_data/g2-reviews
# nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.csv
# nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.xlsx
# nlp_data/google-business-reviews
# nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.csv
# nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.csv
# nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.xlsx
# nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.csv
# nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.xlsx
# nlp_data/google-play-reviews
# nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.csv
# nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.xlsx
# nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.csv
# nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.xlsx
# nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.csv
# nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.xlsx
# nlp_data/tripadvisor-reviews
# nlp_data/tripadvisor-reviews/.DS_Store
# nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.csv
# nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.xlsx
# nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.csv
# nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.xlsx
# nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.csv
# nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.xlsx
# nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.csv
# nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.xlsx
# nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.csv
# nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.xlsx
# nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.csv
# nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.xlsx
# nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.csv
# nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.xlsx
# nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.csv
# nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.xlsx
# nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.csv
# nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.xlsx
# nlp_data/trustpilot-reviews
# nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.csv
# nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.xlsx
# nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.csv
# nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.xlsx
# nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) - Trustpilot Product Reviews - English.csv
# nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) -Trustpilot Product Reviews - English.xlsx
# nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.csv
# nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.xlsx
# nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.csv
# nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.xlsx
# nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.csv
# nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.xlsx
# nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.csv
# nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.xlsx
# nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.csv
# nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.xlsx
# nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.csv
# nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.xlsx
# nlp_data/udemy-reviews
# nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.csv
# nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.xlsx
# nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.csv
# nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.xlsx
# nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.csv
# nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.xlsx
# nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.csv
# nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.xlsx
# nlp_data/udemy-reviews/etsy-product-reviews
# nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv
# nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx
# nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv
# nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx
# product_eval
# product_eval/test-00000-of-00003.parquet
# product_eval/test-00001-of-00003.parquet
# product_eval/test-00002-of-00003.parquet

# %%
# Remplacez par vos informations
account_name = "datalakedeviavals"
container_name = "data"

# Créer une connexion BlobServiceClient
connection_string = f"DefaultEndpointsProtocol=https;AccountName={account_name};AccountKey={account_key};EndpointSuffix=core.windows.net"
blob_service_client = BlobServiceClient.from_connection_string(connection_string)

# Accéder à un conteneur
container_client = blob_service_client.get_container_client(container_name)

print(f"Connexion réussie au conteneur {container_name}.")

# Chemin du dossier local où les fichiers seront sauvegardés
local_folder = "./downloads"
os.makedirs(local_folder, exist_ok=True)

# Liste et téléchargement des blobs
print("Téléchargement des blobs disponibles :")
for blob in container_client.list_blobs():
    blob_name = blob.name
    local_file_path = os.path.join(local_folder, blob_name)

    # Vérifiez si un fichier ou un répertoire existe déjà
    parent_dir = os.path.dirname(local_file_path)
    if os.path.exists(parent_dir):
        if os.path.isfile(parent_dir):
            # Si un fichier existe avec le même nom, le supprimer
            os.remove(parent_dir)

    # Créez les répertoires nécessaires
    os.makedirs(parent_dir, exist_ok=True)

    # Télécharger le blob
    with open(local_file_path, "wb") as file:
        blob_data = container_client.download_blob(blob_name)
        file.write(blob_data.readall())

    print(f"Blob '{blob_name}' téléchargé dans '{local_file_path}'.")

print("Tous les blobs ont été téléchargés avec succès.")
# Out:
# Connexion réussie au conteneur data.
# Téléchargement des blobs disponibles :
# Blob 'machine_learning' téléchargé dans './downloads/machine_learning'.
# Blob 'machine_learning/reviews.zip' téléchargé dans './downloads/machine_learning/reviews.zip'.
# Blob 'nlp_data' téléchargé dans './downloads/nlp_data'.
# Blob 'nlp_data/amazon-product-reviews' téléchargé dans './downloads/nlp_data/amazon-product-reviews'.
# Blob 'nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Apple Magic Mouse (Technology) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Dior Sauvage (Perfume) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Huggies (Baby Wipes) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Nike, Air Jordan (Sports shoes) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Nintendo Switch (Gaming) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.csv' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.csv'.
# Blob 'nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.xlsx' téléchargé dans './downloads/nlp_data/amazon-product-reviews/Samsonite (Luggage) - Amazon Product Reviews.xlsx'.
# Blob 'nlp_data/app-store-reviews' téléchargé dans './downloads/nlp_data/app-store-reviews'.
# Blob 'nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.csv' téléchargé dans './downloads/nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.csv'.
# Blob 'nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.xlsx' téléchargé dans './downloads/nlp_data/app-store-reviews/Calm (Meditation App) - App Store Reviews.xlsx'.
# Blob 'nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.csv' téléchargé dans './downloads/nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.csv'.
# Blob 'nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.xlsx' téléchargé dans './downloads/nlp_data/app-store-reviews/Netflix (IPTV) - App Store Reviews.xlsx'.
# Blob 'nlp_data/etsy-reviews' téléchargé dans './downloads/nlp_data/etsy-reviews'.
# Blob 'nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv'.
# Blob 'nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/etsy-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx'.
# Blob 'nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv'.
# Blob 'nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/etsy-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx'.
# Blob 'nlp_data/g2-reviews' téléchargé dans './downloads/nlp_data/g2-reviews'.
# Blob 'nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.csv' téléchargé dans './downloads/nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.csv'.
# Blob 'nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.xlsx' téléchargé dans './downloads/nlp_data/g2-reviews/Hubspot (SaaS Company) - G2 Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews' téléchargé dans './downloads/nlp_data/google-business-reviews'.
# Blob 'nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/AbsoluteYou (Fitness Center in Singapore) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Borsalino (Hat Boutique in Milan) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Carita (Beauty Salon in Paris) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Disneyland (Theme Park) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Eiffel Tower (Attraction) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/LEGO Store (Toy Company) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Planet13 (Cannabis Store in LA) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Topkapi Palace (Attraction in Istanbul) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.csv' téléchargé dans './downloads/nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.csv'.
# Blob 'nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-business-reviews/Walmart (Retail Company) - Google Business Reviews.xlsx'.
# Blob 'nlp_data/google-play-reviews' téléchargé dans './downloads/nlp_data/google-play-reviews'.
# Blob 'nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.csv' téléchargé dans './downloads/nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.csv'.
# Blob 'nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-play-reviews/Candy Crush (Mobile Game) - Google Play Reviews.xlsx'.
# Blob 'nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.csv' téléchargé dans './downloads/nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.csv'.
# Blob 'nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-play-reviews/Spotify (Streaming App) - Google Play Reviews.xlsx'.
# Blob 'nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.csv' téléchargé dans './downloads/nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.csv'.
# Blob 'nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.xlsx' téléchargé dans './downloads/nlp_data/google-play-reviews/Subway Surfers (Mobile Game) - Google Play Reviews.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews' téléchargé dans './downloads/nlp_data/tripadvisor-reviews'.
# Blob 'nlp_data/tripadvisor-reviews/.DS_Store' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/.DS_Store'.
# Blob 'nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Alfama (Travel Agency) - Tripadvisor Customer Reviews - Portuguese.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.csv'.
# Blob 'nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/British Museum (Attraction) - Tripadvisor Reviews.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Clerigos Tower (Attraction) - Tripadvisor Customer Reviews - Portuguese.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Giolitti (Ice Cream Shop in Rome) - Tripadvisor Reviews.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Granvia Kyoto (Hotel) - Tripadvisor Customer Reviews - Japanese.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.csv'.
# Blob 'nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/K3 New Delhi (Restaurant) - Tripadvisor Customer Reviews - Swedish.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Li Bai Authentic Cantonese (Restaurant) - Tripadvisor Customer Review - Vietnamese.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.csv'.
# Blob 'nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/Shinok (Restaurant) - Tripadvisor Customer Reviews - Russian.xlsx'.
# Blob 'nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.csv' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.csv'.
# Blob 'nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.xlsx' téléchargé dans './downloads/nlp_data/tripadvisor-reviews/War Remnants (Museum) - Tripadvisor Customer Reviews - Japanese.xlsx'.
# Blob 'nlp_data/trustpilot-reviews' téléchargé dans './downloads/nlp_data/trustpilot-reviews'.
# Blob 'nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.csv'.
# Blob 'nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Autohero French (Car Dealer) - Truspilot Customer Reviews - French.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.csv'.
# Blob 'nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Businesscaffe.it (Coffee Shop) - Trustpilot Customer Reviews - Italian.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) - Trustpilot Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) - Trustpilot Product Reviews - English.csv'.
# Blob 'nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) -Trustpilot Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Dog Tag Art (Pet Store) -Trustpilot Product Reviews - English.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.csv'.
# Blob 'nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/FRU.PL (Travel Agency) - Trustpilot Customer Reviews - Polish.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.csv'.
# Blob 'nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Green Lake (Jewelry) - Trustpilot Product Reviews - English.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.csv'.
# Blob 'nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/K11 Ersatzteilshop GmbH (Electronics Store) - Trustpilot Customer Reviews - German.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.csv'.
# Blob 'nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/Kimaccessori.it (Shopping&Fashion) - Trustpilot Product Reviews - Italian.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.csv'.
# Blob 'nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/N”jesresor.se (Travel Agency) - Trustpilot Customer Reviews - Swedish.xlsx'.
# Blob 'nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.csv' téléchargé dans './downloads/nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.csv'.
# Blob 'nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.xlsx' téléchargé dans './downloads/nlp_data/trustpilot-reviews/United Airlines (Airline Company) - Trustpilot Reviews.xlsx'.
# Blob 'nlp_data/udemy-reviews' téléchargé dans './downloads/nlp_data/udemy-reviews'.
# Blob 'nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.csv'.
# Blob 'nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/CSS Course (Digital Course) - Udemy User Reviews - Spanish.xlsx'.
# Blob 'nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.csv'.
# Blob 'nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/Google Ads for Beginners (Digital Course) - Udemy User Reviews - English.xlsx'.
# Blob 'nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.csv'.
# Blob 'nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/Robin&Jesper (Digital Marketing) - Udemy User Reviews - English.xlsx'.
# Blob 'nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.csv'.
# Blob 'nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/Web Development (Digital Course) - Udemy User Reviews - English.xlsx'.
# Blob 'nlp_data/udemy-reviews/etsy-product-reviews' téléchargé dans './downloads/nlp_data/udemy-reviews/etsy-product-reviews'.
# Blob 'nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.csv'.
# Blob 'nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/etsy-product-reviews/Dezaart Wood Pendant Light (Design Company) - Etsy Product Reviews - English.xlsx'.
# Blob 'nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv' téléchargé dans './downloads/nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.csv'.
# Blob 'nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx' téléchargé dans './downloads/nlp_data/udemy-reviews/etsy-product-reviews/Robot Baby (Toys) - Etsy Product Reviews - English.xlsx'.
# Blob 'product_eval' téléchargé dans './downloads/product_eval'.
# Blob 'product_eval/test-00000-of-00003.parquet' téléchargé dans './downloads/product_eval/test-00000-of-00003.parquet'.
# Blob 'product_eval/test-00001-of-00003.parquet' téléchargé dans './downloads/product_eval/test-00001-of-00003.parquet'.
# Blob 'product_eval/test-00002-of-00003.parquet' téléchargé dans './downloads/product_eval/test-00002-of-00003.parquet'.
# Tous les blobs ont été téléchargés avec succès.
